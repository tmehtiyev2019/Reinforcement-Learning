# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=6
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1

        while True:

            
            
            # Choose action using epsilon-greedy strategy

#             action = np.argmax(Q[world_id, state])
            if random.uniform(0, 1) <= adjusted_epsilon:
                if state_row != 20:
                    if state_row<20:
                        action=2
                    elif state_row>20:
                        action=3


            elif:
                if state_col!=30:
                    if state_col<30:
                        action=0
                    elif state_col>30:
                        action=1     
#             elif:
#                 state_row==20 and state_col==30:
#                 action=1
#                 action = np.argmax(Q[world_id, state])

#                 if Q[world_id, state, action]!= np.argmin(Q[world_id, state]) or Q[world_id, state, action]==0:
#                     break

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.   3.   2.   2. 186.   7. 132.   2.   2.   2.   2.]
# 6  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.1, 'scoreIncrement': 0.1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  35634.63000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.11, 'scoreIncrement': 0.1, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35634.74000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.11, 'scoreIncrement': 0.09, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   2
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35634.85000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.11, 'scoreIncrement': 0.08, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   1
# Current state:  42
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35634.96000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.1, 'scoreIncrement': 0.07, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.1
# cumulative reward from the world so far:  35635.06000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.1, 'scoreIncrement': 0.06, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  35635.16000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.1, 'scoreIncrement': 0.05, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  35635.26000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.11, 'scoreIncrement': 0.05, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35635.37000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.11, 'scoreIncrement': 0.05, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35635.48000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.11, 'scoreIncrement': 0.04, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   3
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35635.59000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.11, 'scoreIncrement': 0.04, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35635.70000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.12, 'scoreIncrement': 0.04, 'newState': {'x': '1', 'y': 5}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   5
# Current state:  44
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35635.82000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.11, 'scoreIncrement': 0.03, 'newState': {'x': 0, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  0   5
# Current state:  45
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35635.93000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.12, 'scoreIncrement': 0.03, 'newState': {'x': '0', 'y': 6}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  0   6
# Current state:  5
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35636.050000003655
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.12, 'scoreIncrement': 0.03, 'newState': {'x': 1, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   6
# Current state:  6
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35636.17000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.12, 'scoreIncrement': 0.02, 'newState': {'x': '1', 'y': 7}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   7
# Current state:  46
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35636.29000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.13, 'scoreIncrement': 0.02, 'newState': {'x': '1', 'y': 8}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   8
# Current state:  47
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  35636.42000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.13, 'scoreIncrement': 0.02, 'newState': {'x': '1', 'y': 9}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   9
# Current state:  48
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  35636.550000003655
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.13, 'scoreIncrement': 0.02, 'newState': {'x': 2, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  2   9
# Current state:  49
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  35636.68000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.14, 'scoreIncrement': 0.02, 'newState': {'x': 3, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  3   9
# Current state:  89
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  35636.82000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.14, 'scoreIncrement': 0.02, 'newState': {'x': 4, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   9
# Current state:  129
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  35636.96000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.14, 'scoreIncrement': 0.02, 'newState': {'x': 5, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  5   9
# Current state:  169
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  35637.10000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.15, 'scoreIncrement': 0.01, 'newState': {'x': '5', 'y': 10}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  5   10
# Current state:  209
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  35637.25000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.15, 'scoreIncrement': 0.01, 'newState': {'x': 6, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  6   10
# Current state:  210
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  35637.400000003654
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0.01, 'newState': {'x': '6', 'y': 11}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  6   11
# Current state:  250
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35637.56000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.15, 'scoreIncrement': 0.01, 'newState': {'x': '6', 'y': 10}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  6   10
# Current state:  251
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  35637.71000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0.01, 'newState': {'x': 7, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  7   10
# Current state:  250
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35637.87000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0.01, 'newState': {'x': '7', 'y': 11}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  7   11
# Current state:  290
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35638.030000003666
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.17, 'scoreIncrement': 0.01, 'newState': {'x': 8, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  8   11
# Current state:  291
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35638.200000003664
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.17, 'scoreIncrement': 0.01, 'newState': {'x': '8', 'y': 12}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  8   12
# Current state:  331
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35638.37000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.18, 'scoreIncrement': 0.01, 'newState': {'x': 9, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  9   12
# Current state:  332
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.18
# cumulative reward from the world so far:  35638.55000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': '9', 'y': 13}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  9   13
# Current state:  372
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  35638.740000003665
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': '9', 'y': 14}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  9   14
# Current state:  373
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  35638.93000000367
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.2, 'scoreIncrement': 0.01, 'newState': {'x': '9', 'y': 15}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  9   15
# Current state:  374
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.2
# cumulative reward from the world so far:  35639.130000003664
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.21, 'scoreIncrement': 0.01, 'newState': {'x': 10, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  10   15
# Current state:  375
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.21
# cumulative reward from the world so far:  35639.34000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.22, 'scoreIncrement': 0.01, 'newState': {'x': 11, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  11   15
# Current state:  415
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.22
# cumulative reward from the world so far:  35639.560000003665
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.23, 'scoreIncrement': 0.01, 'newState': {'x': '11', 'y': 16}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  11   16
# Current state:  455
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.23
# cumulative reward from the world so far:  35639.79000000367
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 17}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  11   17
# Current state:  456
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.24
# cumulative reward from the world so far:  35640.030000003666
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': 12, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  12   17
# Current state:  457
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.25
# cumulative reward from the world so far:  35640.280000003666
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': 13, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  13   17
# Current state:  497
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.26
# cumulative reward from the world so far:  35640.54000000367
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': 12, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  12   17
# Current state:  537
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.25
# cumulative reward from the world so far:  35640.79000000367
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': '12', 'y': 16}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  12   16
# Current state:  497
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.24
# cumulative reward from the world so far:  35641.030000003666
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': 13, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  13   16
# Current state:  496
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.25
# cumulative reward from the world so far:  35641.280000003666
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': 14, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  14   16
# Current state:  536
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.26
# cumulative reward from the world so far:  35641.54000000367
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.28, 'scoreIncrement': 0, 'newState': {'x': 15, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  15   16
# Current state:  576
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.28
# cumulative reward from the world so far:  35641.82000000367
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.29, 'scoreIncrement': 0, 'newState': {'x': 16, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  16   16
# Current state:  616
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.29
# cumulative reward from the world so far:  35642.11000000367
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.31, 'scoreIncrement': 0, 'newState': {'x': 17, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  17   16
# Current state:  656
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.31
# cumulative reward from the world so far:  35642.420000003665
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.33, 'scoreIncrement': 0, 'newState': {'x': 18, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  18   16
# Current state:  696
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.33
# cumulative reward from the world so far:  35642.75000000367
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.36, 'scoreIncrement': 0, 'newState': {'x': '18', 'y': 17}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  18   17
# Current state:  736
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.36
# cumulative reward from the world so far:  35643.11000000367
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.38, 'scoreIncrement': 0, 'newState': {'x': '18', 'y': 18}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  18   18
# Current state:  737
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.38
# cumulative reward from the world so far:  35643.490000003665
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.42, 'scoreIncrement': 0, 'newState': {'x': 19, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  19   18
# Current state:  738
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.42
# cumulative reward from the world so far:  35643.91000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': '19', 'y': 19}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  19   19
# Current state:  778
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.45
# cumulative reward from the world so far:  35644.36000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': 20, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  20   19
# Current state:  779
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35644.86000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': 21, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   19
# Current state:  819
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.56
# cumulative reward from the world so far:  35645.42000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': '21', 'y': 20}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   20
# Current state:  859
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.63
# cumulative reward from the world so far:  35646.050000003655
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.71, 'scoreIncrement': 0, 'newState': {'x': '21', 'y': 21}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   21
# Current state:  860
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.71
# cumulative reward from the world so far:  35646.760000003655
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': '21', 'y': 22}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   22
# Current state:  861
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  35647.590000003656
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 22, 'y': '22'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   22
# Current state:  862
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35648.590000003656
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': 21, 'y': '22'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   22
# Current state:  902
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  35649.42000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '21', 'y': 23}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   23
# Current state:  862
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35650.42000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': '21', 'y': 24}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   24
# Current state:  863
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.25
# cumulative reward from the world so far:  35651.67000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 20, 'y': '24'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  20   24
# Current state:  864
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35652.67000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': '20', 'y': 25}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  20   25
# Current state:  824
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  35653.50000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 21, 'y': '25'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   25
# Current state:  825
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35654.50000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': 22, 'y': '25'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   25
# Current state:  865
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.25
# cumulative reward from the world so far:  35655.75000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 26}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   26
# Current state:  905
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35656.75000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 27}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   27
# Current state:  906
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  35657.58000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 26}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   26
# Current state:  907
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35658.58000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 27}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   27
# Current state:  906
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  35659.41000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.71, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 28}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   28
# Current state:  907
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.71
# cumulative reward from the world so far:  35660.12000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': 23, 'y': '28'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  23   28
# Current state:  908
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.83
# cumulative reward from the world so far:  35660.950000003664
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 24, 'y': '28'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   28
# Current state:  948
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35661.950000003664
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 27}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   27
# Current state:  988
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.25
# cumulative reward from the world so far:  35663.200000003664
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1.67, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 26}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   26
# Current state:  987
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.67
# cumulative reward from the world so far:  35664.87000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 27}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   27
# Current state:  986
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.25
# cumulative reward from the world so far:  35666.12000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 25, 'y': '27'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   27
# Current state:  987
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35667.12000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': 24, 'y': '27'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   27
# Current state:  1027
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.25
# cumulative reward from the world so far:  35668.37000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 28}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   28
# Current state:  987
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35669.37000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 29}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   29
# Current state:  988
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  35670.200000003664
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.71, 'scoreIncrement': 0, 'newState': {'x': 25, 'y': '29'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   29
# Current state:  989
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.71
# cumulative reward from the world so far:  35670.91000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': '25', 'y': 30}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   30
# Current state:  1029
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.63
# cumulative reward from the world so far:  35671.54000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': 26, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   30
# Current state:  1030
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.56
# cumulative reward from the world so far:  35672.10000000366
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': '26', 'y': 29}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   29
# Current state:  1070
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.63
# cumulative reward from the world so far:  35672.730000003656
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': '26', 'y': 30}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   30
# Current state:  1069
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.56
# cumulative reward from the world so far:  35673.29000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': 25, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   30
# Current state:  1070
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.63
# cumulative reward from the world so far:  35673.92000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': '25', 'y': 31}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   31
# Current state:  1030
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.56
# cumulative reward from the world so far:  35674.48000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': '25', 'y': 32}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   32
# Current state:  1031
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35674.98000000365
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': '25', 'y': 33}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   33
# Current state:  1032
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.45
# cumulative reward from the world so far:  35675.430000003646
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': '25', 'y': 32}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   32
# Current state:  1033
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35675.930000003646
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': '25', 'y': 31}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   31
# Current state:  1032
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.56
# cumulative reward from the world so far:  35676.49000000364
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': 26, 'y': '31'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   31
# Current state:  1031
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35676.99000000364
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': '26', 'y': 32}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   32
# Current state:  1071
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.45
# cumulative reward from the world so far:  35677.44000000364
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': '26', 'y': 31}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   31
# Current state:  1072
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35677.94000000364
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': 25, 'y': '31'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   31
# Current state:  1071
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.56
# cumulative reward from the world so far:  35678.50000000364
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': '25', 'y': 32}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   32
# Current state:  1031
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35679.00000000364
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': '25', 'y': 33}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   33
# Current state:  1032
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.45
# cumulative reward from the world so far:  35679.450000003635
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.42, 'scoreIncrement': 0, 'newState': {'x': '25', 'y': 34}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   34
# Current state:  1033
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.42
# cumulative reward from the world so far:  35679.87000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.38, 'scoreIncrement': 0, 'newState': {'x': 26, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   34
# Current state:  1034
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.38
# cumulative reward from the world so far:  35680.25000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.36, 'scoreIncrement': 0, 'newState': {'x': 27, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  27   34
# Current state:  1074
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.36
# cumulative reward from the world so far:  35680.61000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.33, 'scoreIncrement': 0, 'newState': {'x': 28, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  28   34
# Current state:  1114
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.33
# cumulative reward from the world so far:  35680.94000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.31, 'scoreIncrement': 0, 'newState': {'x': '28', 'y': 35}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  28   35
# Current state:  1154
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.31
# cumulative reward from the world so far:  35681.25000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.29, 'scoreIncrement': 0, 'newState': {'x': 29, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  29   35
# Current state:  1155
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.29
# cumulative reward from the world so far:  35681.54000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.28, 'scoreIncrement': 0, 'newState': {'x': 30, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  30   35
# Current state:  1195
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.28
# cumulative reward from the world so far:  35681.82000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': '30', 'y': 36}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  30   36
# Current state:  1235
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.26
# cumulative reward from the world so far:  35682.08000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': 31, 'y': '36'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  31   36
# Current state:  1236
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.25
# cumulative reward from the world so far:  35682.33000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': 32, 'y': '36'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  32   36
# Current state:  1276
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.24
# cumulative reward from the world so far:  35682.57000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': 33, 'y': '36'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  33   36
# Current state:  1316
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.23
# cumulative reward from the world so far:  35682.80000000363
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': '33', 'y': 37}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  33   37
# Current state:  1356
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  35683.020000003635
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': 32, 'y': '37'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  32   37
# Current state:  1357
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.23
# cumulative reward from the world so far:  35683.25000000364
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': 33, 'y': '37'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  33   37
# Current state:  1317
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.22
# cumulative reward from the world so far:  35683.47000000364
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': 32, 'y': '37'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  32   37
# Current state:  1357
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.23
# cumulative reward from the world so far:  35683.70000000364
# printing the response:
# ...
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1598
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35693.800000003685
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35693.96000000369
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35694.12000000369
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35694.280000003695
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35694.4400000037
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35694.6000000037
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35694.760000003705
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35694.92000000371
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35695.08000000371
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': 38, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  38   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35695.25000000371
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': '38', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  38   39
# Current state:  1559
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35695.42000000371
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': '38', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  38   39
# Current state:  1559
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35695.59000000371
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': '38', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  38   39
# Current state:  1559
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35695.760000003705
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1559
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35695.92000000371
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35696.08000000371
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35696.240000003716
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35696.40000000372
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 38}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   38
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35696.57000000372
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': 38, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  38   38
# Current state:  1598
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35696.740000003716
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   38
# Current state:  1558
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35696.910000003714
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1598
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35697.07000000372
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35697.23000000372
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35697.390000003725
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35697.55000000373
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35697.71000000373
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35697.870000003735
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35698.03000000374
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35698.19000000374
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35698.350000003746
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35698.51000000375
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35698.67000000375
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35698.830000003756
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35698.99000000376
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35699.15000000376
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35699.31000000377
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35699.47000000377
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50789', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35699.63000000377

# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=9
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1
        next_state_row, next_state_col=0,0

        while True:
            while True:


                if next_state_row==3 and next_state_col==0:
                    action=1
                    action = np.argmax(Q[world_id, state])


                # Choose action using epsilon-greedy strategy

    #             action = np.argmax(Q[world_id, state])
                elif random.uniform(0, 1) <= adjusted_epsilon:
                    if next_state_row != 3:
                        if next_state_row<3:
                            action=2
                        elif next_state_row>3:
                            action=3


                elif next_state_col!=0:
                    if next_state_col<0:
                        action=0
                    elif next_state_col>0:
                        action=1  
                break
    #             elif:
    #                 state_row==20 and state_col==30:
    #                 action=1
    #                 action = np.argmax(Q[world_id, state])

#                 if Q[world_id, state, action]!= np.argmin(Q[world_id, state]) or Q[world_id, state, action]==0:
#                     break


#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.   4.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40140.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40141.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40142.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40143.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40144.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40145.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40146.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40147.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '3', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  122
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40148.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  4   1
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40149.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  161
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40150.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '3', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  121
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40151.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 10000, 'scoreIncrement': 2824.3, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51913', 'reward': 10000, 'scoreIncrement': 2824.3, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.   5.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  50152.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  50153.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  2
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  50154.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  50155.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   2
# Current state:  2
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  50156.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  50157.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  50158.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '3', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  122
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  50159.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '3', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  121
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  50160.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 10000, 'scoreIncrement': 3874.2, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51915', 'reward': 10000, 'scoreIncrement': 3874.2, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.   6.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60161.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60162.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60163.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60164.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60165.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60166.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60167.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60168.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60169.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60170.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '3', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  60171.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 10000, 'scoreIncrement': 3138.11, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51917', 'reward': 10000, 'scoreIncrement': 3138.11, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.   7.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51919', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  70172.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51919', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  70173.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51919', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  70174.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51919', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  70175.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51919', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  70176.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51919', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  70177.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51919', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  70178.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51919', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  70179.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51919', 'reward': 10000, 'scoreIncrement': 4304.67, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51919', 'reward': 10000, 'scoreIncrement': 4304.67, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.   8.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51921', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  80180.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51921', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  80181.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51921', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  80182.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51921', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51921', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.   9.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90183.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90184.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90185.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90186.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90187.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90188.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90189.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90190.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90191.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90192.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90193.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90194.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90195.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90196.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90197.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90198.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90199.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90200.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  90201.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 10000, 'scoreIncrement': 1350.85, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51922', 'reward': 10000, 'scoreIncrement': 1350.85, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.  10.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51923', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  100202.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51923', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  100203.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51923', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  100204.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51923', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  100205.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51923', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  100206.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51923', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51923', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.  11.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51925', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  110207.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51925', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  110208.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51925', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  110209.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51925', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  110210.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51925', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  4   1
# Current state:  121
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  110211.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51925', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '4', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  4   0
# Current state:  161
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  110212.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51925', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  160
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  110213.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51925', 'reward': 10000, 'scoreIncrement': 4782.97, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51925', 'reward': 10000, 'scoreIncrement': 4782.97, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.  12.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120214.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120215.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120216.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120217.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120218.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   2
# Current state:  2
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120219.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120220.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120221.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': 4, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  4   2
# Current state:  122
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120222.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   2
# Current state:  162
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120223.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '3', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  122
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120224.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  121
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120225.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120226.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  120227.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 10000, 'scoreIncrement': 2287.68, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51926', 'reward': 10000, 'scoreIncrement': 2287.68, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.  13.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51927', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  130228.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51927', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  130229.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51927', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  130230.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51927', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51927', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.  14.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140231.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140232.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140233.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140234.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140235.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140236.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140237.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140238.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140239.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140240.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140241.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140242.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51928', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  140243.0
# printing the response:
# ...
#  {'code': 'OK', 'worldId': 9, 'runId': '51963', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  380479.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51963', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  4   1
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  380480.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51963', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  161
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  380481.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51963', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  121
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  380482.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51963', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  380483.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51963', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  380484.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51963', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  380485.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51963', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': '3', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  121
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  380486.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51963', 'reward': 10000, 'scoreIncrement': 2541.87, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51963', 'reward': 10000, 'scoreIncrement': 2541.87, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.  45.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51964', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  390487.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51964', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  390488.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51964', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  390489.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51964', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  390490.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51964', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  390491.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51964', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51964', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.  46.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51965', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  400492.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51965', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  400493.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51965', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  400494.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51965', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  400495.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51965', 'reward': 10000, 'scoreIncrement': 6561, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51965', 'reward': 10000, 'scoreIncrement': 6561, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.  47.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51966', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  410496.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51966', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  410497.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51966', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  410498.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51966', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  410499.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51966', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  410500.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51966', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  410501.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51966', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  410502.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51966', 'reward': 10000, 'scoreIncrement': 4782.97, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51966', 'reward': 10000, 'scoreIncrement': 4782.97, 'newState': None}
# 9  ended
# 4  episode started
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.  48.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51968', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  420503.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51968', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  420504.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51968', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  420505.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51968', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  420506.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51968', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  420507.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51968', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51968', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# 9  ended
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.  49.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51969', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  430508.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51969', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  430509.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51969', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  430510.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51969', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  430511.0

# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = 1
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=2
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1

        while True:
            
            
            
            
            # Choose action using epsilon-greedy strategy
            
#             action = np.argmax(Q[world_id, state])
            if random.uniform(0, 1) <= adjusted_epsilon:
#                 while True:
#                     a = random.randint(0, 3)
#                     if Q[world_id, state, a]!= np.argmin(Q[world_id, state]) or Q[world_id, state, a]==0:
#                         action=a
#                         break

        
                for a in range(n_actions):
                    if Q[world_id, state, a]==0:
                        action=a
                        break
                    else:
                        action = random.randint(0, 3)
#                         if Q[world_id, state, a]!= np.argmin(Q[world_id, state]):
#                             action=a
                        
#             else :
#                 action=np.argmax(Q[world_id, state])
                        
#                         while True:
#                             a = random.randint(0, 3)
#                             if Q[world_id, state, a]!= np.argmin(Q[world_id, state]):
#                                 action=a
#                                 break
                        

#             else:

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                print("Last action to terminal: ", action )
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        
        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        if reward>0:
            break
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# # Print the learned policy
# for world_id in range(n_worlds):
#     print(f"World {world_id}:")
#     for state in range(n_states):
#         print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.  77.   2.   2. 186.  34. 147.  37.   9.   2.   2.]
# 2  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32297.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32298.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32299.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32300.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32301.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32302.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32303.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   0
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32304.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32305.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   0
# Current state:  120
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32306.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32307.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32308.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   2
# Current state:  82
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32309.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   3
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32310.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': 2, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   3
# Current state:  43
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32311.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   3
# Current state:  83
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32312.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   3
# Current state:  43
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32313.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32314.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   3
# Current state:  3
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32315.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32316.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   3
# Current state:  44
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32317.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   3
# Current state:  43
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32318.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32319.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   3
# Current state:  3
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32320.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32321.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': 2, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   4
# Current state:  44
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32322.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': '2', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   3
# Current state:  84
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32323.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 3, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   3
# Current state:  83
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32324.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 4, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   3
# Current state:  123
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32325.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 5, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   3
# Current state:  163
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32326.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 4, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   3
# Current state:  203
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32327.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 3, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   3
# Current state:  163
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32328.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 2, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   3
# Current state:  123
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32329.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   3
# Current state:  83
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32330.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 2, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   3
# Current state:  43
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32331.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   3
# Current state:  83
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32332.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32333.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': 2, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   4
# Current state:  44
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32334.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': 3, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   4
# Current state:  84
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32335.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': 2, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   4
# Current state:  124
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32336.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 3, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   4
# Current state:  84
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32337.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 4, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   4
# Current state:  124
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32338.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 5, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   4
# Current state:  164
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32339.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '5', 'y': 5}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   5
# Current state:  204
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32340.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '5', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   4
# Current state:  205
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32341.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 6, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   4
# Current state:  204
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32342.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '6', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   3
# Current state:  244
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32343.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '6', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   2
# Current state:  243
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32344.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 7, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   2
# Current state:  242
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32345.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '7', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   1
# Current state:  282
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32346.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '7', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   2
# Current state:  281
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32347.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 8, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   2
# Current state:  282
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32348.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '8', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   3
# Current state:  322
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32349.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '8', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   2
# Current state:  323
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32350.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 7, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   2
# Current state:  322
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32351.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 6, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   2
# Current state:  282
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32352.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   2
# Current state:  242
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32353.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 6, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   2
# Current state:  202
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32354.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   1
# Current state:  242
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32355.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   2
# Current state:  241
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32356.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   3
# Current state:  242
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32357.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   3
# Current state:  243
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32358.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   3
# Current state:  203
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32359.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   4
# Current state:  163
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32360.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   3
# Current state:  164
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32361.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   2
# Current state:  163
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32362.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   1
# Current state:  162
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32363.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   1
# Current state:  161
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32364.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '5', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   2
# Current state:  201
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32365.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   2
# Current state:  202
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32366.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   2
# Current state:  162
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32367.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   2
# Current state:  122
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32368.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '2', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   3
# Current state:  82
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32369.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 3, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   3
# Current state:  83
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32370.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '3', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   2
# Current state:  123
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32371.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '3', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   1
# Current state:  122
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32372.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   1
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32373.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   1
# Current state:  161
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32374.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   1
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32375.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   0
# Current state:  161
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32376.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   0
# Current state:  160
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32377.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   0
# Current state:  160
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32378.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '5', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   1
# Current state:  200
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32379.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '5', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   0
# Current state:  201
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32380.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '5', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   0
# Current state:  200
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32381.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 6, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   0
# Current state:  200
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32382.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   1
# Current state:  240
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32383.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   0
# Current state:  241
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32384.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   0
# Current state:  240
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32385.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 7, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   0
# Current state:  240
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32386.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '7', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   1
# Current state:  280
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32387.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '7', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   0
# Current state:  281
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32388.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 8, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   0
# Current state:  280
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32389.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '8', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   1
# Current state:  320
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32390.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 7, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   1
# Current state:  321
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32391.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 8, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   1
# Current state:  281
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32392.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '8', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   0
# Current state:  321
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32393.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   0
# Current state:  320
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32394.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '9', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   1
# Current state:  360
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32395.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 8, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   1
# Current state:  361
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32396.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   1
# Current state:  321
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32397.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '9', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   0
# Current state:  361
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32398.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '9', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   0
# Current state:  360
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32399.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 10, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   0
# Current state:  360
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32400.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   0
# Current state:  400
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32401.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '9', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   1
# Current state:  360
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32402.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 10, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   1
# Current state:  361
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32403.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   1
# Current state:  401
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32404.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 8, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   1
# Current state:  361
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32405.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 7, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   1
# Current state:  321
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32406.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 6, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   1
# Current state:  281
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32407.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 7, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   1
# Current state:  241
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32408.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 6, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   1
# Current state:  281
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32409.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   1
# Current state:  241
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32410.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 6, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   1
# Current state:  201
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  32411.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   0
# Current state:  241
# ...
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33210.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  39   39
# Current state:  1559
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33211.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 38}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  39   38
# Current state:  1599
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33212.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  39   39
# Current state:  1598
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33213.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33214.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 38}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  39   38
# Current state:  1599
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33215.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 38, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  38   38
# Current state:  1598
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33216.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '38', 'y': 39}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  38   39
# Current state:  1558
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33217.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 37, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  37   39
# Current state:  1559
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33218.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '37', 'y': 39}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  37   39
# Current state:  1519
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33219.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 36, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  36   39
# Current state:  1519
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33220.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 38}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  36   38
# Current state:  1479
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33221.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 37}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  36   37
# Current state:  1478
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33222.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 36}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  36   36
# Current state:  1477
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33223.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 35}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  36   35
# Current state:  1476
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33224.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 34}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  36   34
# Current state:  1475
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33225.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 33}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  36   33
# Current state:  1474
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33226.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 37, 'y': '33'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  37   33
# Current state:  1473
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33227.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 36, 'y': '33'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  36   33
# Current state:  1513
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33228.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 35, 'y': '33'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  35   33
# Current state:  1473
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33229.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 34, 'y': '33'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  34   33
# Current state:  1433
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33230.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 34}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  34   34
# Current state:  1393
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33231.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 35}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  34   35
# Current state:  1394
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33232.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 36}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  34   36
# Current state:  1395
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33233.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 35, 'y': '36'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  35   36
# Current state:  1396
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33234.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 34, 'y': '36'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  34   36
# Current state:  1436
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33235.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 37}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  34   37
# Current state:  1396
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33236.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 35, 'y': '37'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  35   37
# Current state:  1397
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33237.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 36}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  35   36
# Current state:  1437
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33238.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 35}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  35   35
# Current state:  1436
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33239.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 36, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  36   35
# Current state:  1435
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33240.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 37, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  37   35
# Current state:  1475
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33241.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '37', 'y': 34}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  37   34
# Current state:  1515
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33242.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 36, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  36   34
# Current state:  1514
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33243.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 37, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  37   34
# Current state:  1474
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33244.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 38, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  38   34
# Current state:  1514
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33245.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '38', 'y': 33}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  38   33
# Current state:  1554
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33246.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '33'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  39   33
# Current state:  1553
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33247.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51440', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 32}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  39   32
# Current state:  1593
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  33248.0

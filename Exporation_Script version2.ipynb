# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = 1
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=3
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1

        while True:
            
            
            
            
            # Choose action using epsilon-greedy strategy
            
#             action = np.argmax(Q[world_id, state])
            if random.uniform(0, 1) <= adjusted_epsilon:
#                 while True:
#                     a = random.randint(0, 3)
#                     if Q[world_id, state, a]!= np.argmin(Q[world_id, state]) or Q[world_id, state, a]==0:
#                         action=a
#                         break

        
                for a in range(n_actions):
                    if Q[world_id, state, a]==0:
                        action=a
                        break
                    else:
                        action = random.randint(0, 3)
#                         if Q[world_id, state, a]!= np.argmin(Q[world_id, state]):
#                             action=a
                        
#             else :
#                 action=np.argmax(Q[world_id, state])
                        
#                         while True:
#                             a = random.randint(0, 3)
#                             if Q[world_id, state, a]!= np.argmin(Q[world_id, state]):
#                                 action=a
#                                 break
                        

#             else:

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                print("Last action to terminal: ", action )
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        
        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        if reward>0:
            break
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# # Print the learned policy
# for world_id in range(n_worlds):
#     print(f"World {world_id}:")
#     for state in range(n_states):
#         print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.  77.  17.   2. 186.  34. 147.  37.   9.   2.   2.]
# 3  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51753', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -20005.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51753', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -20006.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51753', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -20007.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51753', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -20008.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51753', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -20009.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51753', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -20010.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51753', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -20011.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51753', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -20012.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51753', 'reward': -10000, 'scoreIncrement': -4304.67, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 3, 'runId': '51753', 'reward': -10000, 'scoreIncrement': -4304.67, 'newState': None}
# Last action to terminal:  0
# 3  ended
# [  0.  77.  17.   3. 186.  34. 147.  37.   9.   2.   2.]
# 3  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30013.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30014.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30015.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  40
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30016.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30017.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30018.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30019.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': '0', 'y': 4}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   4
# Current state:  3
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30020.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.43, 'newState': {'x': '0', 'y': 5}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   5
# Current state:  4
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30021.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.39, 'newState': {'x': '0', 'y': 6}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   6
# Current state:  5
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30022.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.35, 'newState': {'x': '0', 'y': 7}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   7
# Current state:  6
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30023.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.31, 'newState': {'x': '0', 'y': 8}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   8
# Current state:  7
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30024.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.28, 'newState': {'x': '0', 'y': 9}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   9
# Current state:  8
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30025.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.25, 'newState': {'x': '0', 'y': 10}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   10
# Current state:  9
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30026.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.23, 'newState': {'x': '0', 'y': 11}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   11
# Current state:  10
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30027.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.21, 'newState': {'x': '0', 'y': 12}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   12
# Current state:  11
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30028.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.19, 'newState': {'x': '0', 'y': 13}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   13
# Current state:  12
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30029.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.17, 'newState': {'x': '0', 'y': 14}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   14
# Current state:  13
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30030.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.15, 'newState': {'x': '0', 'y': 15}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   15
# Current state:  14
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30031.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.14, 'newState': {'x': '0', 'y': 16}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   16
# Current state:  15
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30032.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.12, 'newState': {'x': '0', 'y': 17}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   17
# Current state:  16
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30033.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.11, 'newState': {'x': '0', 'y': 18}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   18
# Current state:  17
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30034.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.1, 'newState': {'x': '0', 'y': 19}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   19
# Current state:  18
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30035.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.09, 'newState': {'x': '0', 'y': 20}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   20
# Current state:  19
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30036.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.08, 'newState': {'x': '0', 'y': 21}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   21
# Current state:  20
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30037.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.07, 'newState': {'x': '0', 'y': 22}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   22
# Current state:  21
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30038.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': '0', 'y': 23}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   23
# Current state:  22
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30039.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': '0', 'y': 24}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   24
# Current state:  23
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30040.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '0', 'y': 25}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   25
# Current state:  24
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30041.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '0', 'y': 26}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   26
# Current state:  25
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30042.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '0', 'y': 27}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   27
# Current state:  26
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30043.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51754', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '0', 'y': 28}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0
}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  14   38
# Current state:  599
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -30117.0
# printing the response:
# ...
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51758', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -50221.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51758', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -50222.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51758', 'reward': -10000, 'scoreIncrement': -6561, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 3, 'runId': '51758', 'reward': -10000, 'scoreIncrement': -6561, 'newState': None}
# Last action to terminal:  2
# 3  ended
# [  0.  77.  17.   6. 186.  34. 147.  37.   9.   2.   2.]
# 3  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51759', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -60223.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51759', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -60224.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51759', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -60225.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51759', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -60226.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51759', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   0
# Current state:  80
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -60227.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51759', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -60228.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51759', 'reward': -10000, 'scoreIncrement': -5314.41, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 3, 'runId': '51759', 'reward': -10000, 'scoreIncrement': -5314.41, 'newState': None}
# Last action to terminal:  3
# 3  ended
# [  0.  77.  17.   7. 186.  34. 147.  37.   9.   2.   2.]
# 3  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51760', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -70229.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51760', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -70230.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51760', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -70231.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51760', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  40
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -70232.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51760', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -70233.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51760', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -70234.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51760', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -70235.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51760', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -70236.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51760', 'reward': -10000, 'scoreIncrement': -4304.67, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 3, 'runId': '51760', 'reward': -10000, 'scoreIncrement': -4304.67, 'newState': None}
# Last action to terminal:  1
# 3  ended
# [  0.  77.  17.   8. 186.  34. 147.  37.   9.   2.   2.]
# 3  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51761', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -80237.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51761', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -80238.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51761', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -80239.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51761', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -80240.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51761', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   1
# Current state:  1
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -80241.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51761', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -80242.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51761', 'reward': -10000, 'scoreIncrement': -5314.41, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 3, 'runId': '51761', 'reward': -10000, 'scoreIncrement': -5314.41, 'newState': None}
# Last action to terminal:  3
# 3  ended
# [  0.  77.  17.   9. 186.  34. 147.  37.   9.   2.   2.]
# 3  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51762', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -90243.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51762', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   1
# Current state:  1
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -90244.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51762', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -90245.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51762', 'reward': -10000, 'scoreIncrement': -7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 3, 'runId': '51762', 'reward': -10000, 'scoreIncrement': -7290, 'newState': None}
# Last action to terminal:  1
# 3  ended
# [  0.  77.  17.  10. 186.  34. 147.  37.   9.   2.   2.]
# 3  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51764', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -100246.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51764', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -100247.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51764', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -100248.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51764', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -100249.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51764', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': '3', 'y': 0}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  3   0
# Current state:  120
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -100250.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51764', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': 4, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  4   0
# Current state:  120
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -100251.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51764', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': '4', 'y': 1}}
# Visual of the given details is printed above
# World Number:  3
# Current state row and column:  4   1
# Current state:  160
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -100252.0
# printing the response:
#  {'code': 'OK', 'worldId': 3, 'runId': '51764', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': '4', 'y': 2}}

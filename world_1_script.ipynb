# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 1000
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
#         if min(world_traversal_count[1:])<minimum_traversal_requirement:
#             world_id=np.argmin(world_traversal_count[1:])+1
#             print(world_traversal_count)
#         else:
#             world_id=np.argmax(score_map[1:])+1
#             print(score_map)

        world_id=1
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1
        next_state_row, next_state_col=0,0

        while True:
            while True:


                if next_state_row==24 and next_state_col==24:
                    action=1
                    action = np.argmax(Q[world_id, state])


                # Choose action using epsilon-greedy strategy

    #             action = np.argmax(Q[world_id, state])
                elif random.uniform(0, 1) <= adjusted_epsilon:
                    if next_state_row != 24:
                        if next_state_row<24:
                            action=2
                        elif next_state_row>24:
                            action=3


                elif next_state_col!=24:
                    if next_state_col<24:
                        action=0
                    elif next_state_col>24:
                        action=1     
    #             elif:
    #                 state_row==20 and state_col==30:
    #                 action=1
    #                 action = np.argmax(Q[world_id, state])

                if Q[world_id, state, action]!= np.argmin(Q[world_id, state]) or Q[world_id, state, action]==0:
                    break

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# 1  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.1, 'scoreIncrement': 0.1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.1
# cumulative reward from the world so far:  435035.89999999834
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.11, 'scoreIncrement': 0.1, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  435036.0099999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.1, 'scoreIncrement': 0.08, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.1
# cumulative reward from the world so far:  435036.1099999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.11, 'scoreIncrement': 0.08, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  435036.2199999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.11, 'scoreIncrement': 0.07, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  435036.32999999827
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.11, 'scoreIncrement': 0.06, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   3
# Current state:  3
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  435036.43999999826
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.11, 'scoreIncrement': 0.06, 'newState': {'x': 2, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   3
# Current state:  43
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  435036.54999999824
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.12, 'scoreIncrement': 0.06, 'newState': {'x': '2', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   4
# Current state:  83
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  435036.66999999824
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': '2', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   5
# Current state:  84
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  435036.78999999823
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': 3, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  3   5
# Current state:  85
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  435036.9099999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.13, 'scoreIncrement': 0.05, 'newState': {'x': 4, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  4   5
# Current state:  125
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  435037.03999999823
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.13, 'scoreIncrement': 0.04, 'newState': {'x': '4', 'y': 6}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  4   6
# Current state:  165
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  435037.16999999824
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.13, 'scoreIncrement': 0.04, 'newState': {'x': 5, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  5   6
# Current state:  166
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  435037.29999999824
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.14, 'scoreIncrement': 0.04, 'newState': {'x': 6, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   6
# Current state:  206
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  435037.43999999826
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.14, 'scoreIncrement': 0.03, 'newState': {'x': '6', 'y': 7}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   7
# Current state:  246
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  435037.57999999827
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.14, 'scoreIncrement': 0.03, 'newState': {'x': '6', 'y': 8}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   8
# Current state:  247
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  435037.7199999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.15, 'scoreIncrement': 0.03, 'newState': {'x': '6', 'y': 9}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   9
# Current state:  248
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  435037.8699999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.15, 'scoreIncrement': 0.03, 'newState': {'x': '6', 'y': 10}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   10
# Current state:  249
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  435038.01999999833
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.15, 'scoreIncrement': 0.02, 'newState': {'x': 5, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  5   10
# Current state:  250
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  435038.16999999835
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.15, 'scoreIncrement': 0.02, 'newState': {'x': 6, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   10
# Current state:  210
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  435038.3199999984
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.16, 'scoreIncrement': 0.02, 'newState': {'x': '6', 'y': 11}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   11
# Current state:  250
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  435038.47999999835
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.16, 'scoreIncrement': 0.02, 'newState': {'x': 7, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   11
# Current state:  251
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  435038.6399999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.17, 'scoreIncrement': 0.02, 'newState': {'x': 8, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  8   11
# Current state:  291
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  435038.8099999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.17, 'scoreIncrement': 0.02, 'newState': {'x': '8', 'y': 12}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  8   12
# Current state:  331
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.17
# cumulative reward from the world so far:  435038.9799999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.18, 'scoreIncrement': 0.01, 'newState': {'x': 9, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  9   12
# Current state:  332
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.18
# cumulative reward from the world so far:  435039.1599999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': 10, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  10   12
# Current state:  372
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  435039.3499999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': '10', 'y': 13}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  10   13
# Current state:  412
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  435039.5399999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.2, 'scoreIncrement': 0.01, 'newState': {'x': 11, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   13
# Current state:  413
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.2
# cumulative reward from the world so far:  435039.7399999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.21, 'scoreIncrement': 0.01, 'newState': {'x': 12, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   13
# Current state:  453
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.21
# cumulative reward from the world so far:  435039.9499999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.22, 'scoreIncrement': 0.01, 'newState': {'x': '12', 'y': 14}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   14
# Current state:  493
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.22
# cumulative reward from the world so far:  435040.1699999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.23, 'scoreIncrement': 0.01, 'newState': {'x': 13, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  13   14
# Current state:  494
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.23
# cumulative reward from the world so far:  435040.3999999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.24, 'scoreIncrement': 0.01, 'newState': {'x': 14, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  14   14
# Current state:  534
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.24
# cumulative reward from the world so far:  435040.63999999827
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.25, 'scoreIncrement': 0.01, 'newState': {'x': '14', 'y': 15}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  14   15
# Current state:  574
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.25
# cumulative reward from the world so far:  435040.88999999827
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.24, 'scoreIncrement': 0.01, 'newState': {'x': 13, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  13   15
# Current state:  575
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.24
# cumulative reward from the world so far:  435041.12999999826
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.25, 'scoreIncrement': 0.01, 'newState': {'x': '13', 'y': 16}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  13   16
# Current state:  535
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.25
# cumulative reward from the world so far:  435041.37999999826
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.24, 'scoreIncrement': 0.01, 'newState': {'x': 12, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   16
# Current state:  536
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.24
# cumulative reward from the world so far:  435041.61999999825
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': 0.25, 'scoreIncrement': 0.01, 'newState': {'x': '12', 'y': 17}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   17
# Current state:  496
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.25
# cumulative reward from the world so far:  435041.86999999825
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': -10000, 'scoreIncrement': -202.76, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 1, 'runId': '52357', 'reward': -10000, 'scoreIncrement': -202.76, 'newState': None}
# 1  ended
# 1  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.1, 'scoreIncrement': 0.1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.1
# cumulative reward from the world so far:  425041.9699999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.11, 'scoreIncrement': 0.1, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  425042.0799999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.11, 'scoreIncrement': 0.09, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   2
# Current state:  2
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  425042.1899999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.11, 'scoreIncrement': 0.08, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   3
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  425042.2999999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.11, 'scoreIncrement': 0.07, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  425042.40999999817
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.12, 'scoreIncrement': 0.07, 'newState': {'x': 2, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   4
# Current state:  44
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  425042.52999999817
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.12, 'scoreIncrement': 0.06, 'newState': {'x': '2', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   5
# Current state:  84
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  425042.64999999816
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.12, 'scoreIncrement': 0.06, 'newState': {'x': '2', 'y': 6}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   6
# Current state:  85
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  425042.76999999816
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': 1, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   6
# Current state:  86
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  425042.88999999815
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': '1', 'y': 7}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   7
# Current state:  46
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  425043.00999999815
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.13, 'scoreIncrement': 0.05, 'newState': {'x': 2, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   7
# Current state:  47
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  425043.13999999815
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.13, 'scoreIncrement': 0.04, 'newState': {'x': '2', 'y': 8}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   8
# Current state:  87
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  425043.26999999816
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.13, 'scoreIncrement': 0.04, 'newState': {'x': '2', 'y': 7}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   7
# Current state:  88
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  425043.39999999816
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.13, 'scoreIncrement': 0.03, 'newState': {'x': 3, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  3   7
# Current state:  87
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  425043.52999999817
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.13, 'scoreIncrement': 0.03, 'newState': {'x': 4, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  4   7
# Current state:  127
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  425043.65999999817
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.14, 'scoreIncrement': 0.03, 'newState': {'x': '4', 'y': 8}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  4   8
# Current state:  167
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  425043.7999999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.14, 'scoreIncrement': 0.03, 'newState': {'x': '4', 'y': 9}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  4   9
# Current state:  168
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  425043.9399999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.14, 'scoreIncrement': 0.02, 'newState': {'x': 5, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  5   9
# Current state:  169
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  425044.0799999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.15, 'scoreIncrement': 0.02, 'newState': {'x': 6, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   9
# Current state:  209
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  425044.22999999824
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.15, 'scoreIncrement': 0.02, 'newState': {'x': '6', 'y': 10}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   10
# Current state:  249
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  425044.37999999826
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.16, 'scoreIncrement': 0.02, 'newState': {'x': 7, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   10
# Current state:  250
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  425044.53999999823
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.15, 'scoreIncrement': 0.02, 'newState': {'x': '7', 'y': 9}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   9
# Current state:  290
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  425044.68999999826
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.15, 'scoreIncrement': 0.01, 'newState': {'x': 6, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   9
# Current state:  289
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  425044.8399999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.15, 'scoreIncrement': 0.01, 'newState': {'x': 7, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   9
# Current state:  249
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  425044.9899999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.16, 'scoreIncrement': 0.01, 'newState': {'x': 8, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  8   9
# Current state:  289
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  425045.1499999983
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.16, 'scoreIncrement': 0.01, 'newState': {'x': 9, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  9   9
# Current state:  329
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  425045.30999999825
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.17, 'scoreIncrement': 0.01, 'newState': {'x': '9', 'y': 10}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  9   10
# Current state:  369
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  425045.47999999824
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.17, 'scoreIncrement': 0.01, 'newState': {'x': 10, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  10   10
# Current state:  370
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  425045.6499999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.18, 'scoreIncrement': 0.01, 'newState': {'x': '10', 'y': 11}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  10   11
# Current state:  410
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.18
# cumulative reward from the world so far:  425045.8299999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': 11, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   11
# Current state:  411
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  425046.0199999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': '11', 'y': 12}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   12
# Current state:  451
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  425046.2099999982
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '52358', 'reward': 0.2, 'scoreIncrement': 0.01, 'newState': {'x': 12, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   12
# Current state:  452
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.2
# cumulative reward from the world so far:  425046.4099999982

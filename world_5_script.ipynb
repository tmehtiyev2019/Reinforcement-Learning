# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .7
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=5
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1

        while True:
            
            
            # Choose action using epsilon-greedy strategy
            
#             action = np.argmax(Q[world_id, state])
            if random.uniform(0, 1) <= adjusted_epsilon:

            
                for a in range(n_actions):
                    if Q[world_id, state, a]==0:
                        action=0
                        break
                    else:
                        action = np.argmax(Q[world_id, state])
                        break
                        
#                 while True:
#                     a = random.randint(0, n_actions - 1)
#                     if Q[world_id, state, a]>=np.mean(Q[world_id, state]) or Q[world_id, state, a]==0:
#                         action=a
#                         break

            else:
        
                    
        

                action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.   3.   2.   2. 186.   2.   2.   2.   2.   2.   2.]
# 5  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.7
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98191.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98192.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98193.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98194.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98195.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98196.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98197.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98198.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.43, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   2
# Current state:  122
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98199.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.39, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   2
# Current state:  82
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98200.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.35, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   2
# Current state:  42
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98201.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.31, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   1
# Current state:  2
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98202.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.28, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   1
# Current state:  1
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98203.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.25, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98204.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.23, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98205.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.21, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98206.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.19, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   2
# Current state:  2
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98207.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.17, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   3
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98208.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.15, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98209.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.14, 'newState': {'x': '1', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   5
# Current state:  44
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98210.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.12, 'newState': {'x': '1', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   6
# Current state:  45
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98211.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.11, 'newState': {'x': 2, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   6
# Current state:  46
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98212.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.1, 'newState': {'x': '2', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   7
# Current state:  86
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98213.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.09, 'newState': {'x': '2', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   8
# Current state:  87
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98214.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.08, 'newState': {'x': 3, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   8
# Current state:  88
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98215.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.07, 'newState': {'x': '3', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   9
# Current state:  128
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98216.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': 4, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   9
# Current state:  129
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98217.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': 5, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   9
# Current state:  169
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98218.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '5', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   10
# Current state:  209
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98219.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '5', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   11
# Current state:  210
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98220.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '5', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   10
# Current state:  211
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98221.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '5', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   9
# Current state:  210
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98222.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 4, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   9
# Current state:  209
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98223.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 3, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   9
# Current state:  169
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98224.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 2, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   9
# Current state:  129
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98225.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '2', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   8
# Current state:  89
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98226.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '2', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   9
# Current state:  88
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98227.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '2', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   8
# Current state:  89
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98228.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '2', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   7
# Current state:  88
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98229.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': 1, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   7
# Current state:  87
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98230.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '1', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   6
# Current state:  47
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98231.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '1', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   7
# Current state:  46
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98232.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 0, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   7
# Current state:  47
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98233.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '0', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   6
# Current state:  7
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98234.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '0', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   5
# Current state:  6
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98235.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '0', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   6
# Current state:  5
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98236.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 1, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   6
# Current state:  6
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98237.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '1', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   5
# Current state:  46
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98238.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   4
# Current state:  45
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98239.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 2, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   4
# Current state:  44
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98240.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '2', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   3
# Current state:  84
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98241.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '2', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   4
# Current state:  83
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98242.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '2', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   5
# Current state:  84
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98243.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 3, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   5
# Current state:  85
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98244.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   5
# Current state:  125
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98245.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   5
# Current state:  85
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98246.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   5
# Current state:  45
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98247.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '2', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   6
# Current state:  85
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98248.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '2', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   5
# Current state:  86
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98249.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   5
# Current state:  85
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98250.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   6
# Current state:  45
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98251.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   6
# Current state:  46
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98252.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   7
# Current state:  6
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98253.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   7
# Current state:  7
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98254.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   6
# Current state:  7
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98255.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   6
# Current state:  6
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98256.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   7
# Current state:  6
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98257.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   7
# Current state:  7
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98258.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   7
# Current state:  7
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98259.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   6
# Current state:  47
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98260.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   6
# Current state:  46
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98261.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   6
# Current state:  86
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98262.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   7
# Current state:  46
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98263.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   7
# Current state:  47
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98264.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '2', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   6
# Current state:  87
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98265.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '2', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   7
# Current state:  86
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98266.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 3, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   7
# Current state:  87
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98267.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   7
# Current state:  127
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98268.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   8
# Current state:  167
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98269.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   8
# Current state:  168
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98270.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '5', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   9
# Current state:  208
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98271.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 6, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   9
# Current state:  209
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98272.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   8
# Current state:  249
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98273.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   7
# Current state:  248
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98274.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   6
# Current state:  247
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98275.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   5
# Current state:  246
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98276.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   5
# Current state:  245
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98277.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '5', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   4
# Current state:  205
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98278.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '5', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   5
# Current state:  204
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98279.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   5
# Current state:  205
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98280.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   4
# Current state:  165
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98281.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   3
# Current state:  164
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98282.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   2
# Current state:  163
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98283.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   3
# Current state:  162
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98284.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   3
# Current state:  163
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98285.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '5', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   2
# Current state:  203
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98286.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '5', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   1
# Current state:  202
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98287.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 6, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   1
# Current state:  201
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98288.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 7, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   1
# Current state:  241
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98289.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '7', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   2
# Current state:  281
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98290.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '7', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   1
# Current state:  282
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98291.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '7', 'y': 0}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   0
# Current state:  281
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98292.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 8, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   0
# Current state:  280
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98293.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '8', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   1
# Current state:  320
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98294.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '8', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   2
# Current state:  321
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98295.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   2
# Current state:  322
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98296.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '9', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   3
# Current state:  362
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98297.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 10, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   3
# Current state:  363
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98298.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '10', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   4
# Current state:  403
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98299.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '10', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   5
# Current state:  404
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98300.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '10', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   4
# Current state:  405
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98301.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '10', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   3
# Current state:  404
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98302.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '10', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   2
# Current state:  403
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98303.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   2
# Current state:  402
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -98304.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50291', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '9', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   1
# Current state:  362
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# ...
# cumulative reward from the world so far:  -198598.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   10
# Current state:  251
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198599.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   11
# Current state:  250
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198600.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 7, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   11
# Current state:  251
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198601.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '7', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   12
# Current state:  291
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198602.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '7', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   11
# Current state:  292
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198603.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 8, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   11
# Current state:  291
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198604.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   11
# Current state:  331
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198605.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '9', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   10
# Current state:  371
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198606.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 10, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   10
# Current state:  370
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198607.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 11, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   10
# Current state:  410
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198608.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 10, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   10
# Current state:  450
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198609.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   10
# Current state:  410
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198610.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 8, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   10
# Current state:  370
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198611.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   10
# Current state:  330
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198612.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '9', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   11
# Current state:  370
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198613.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 10, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   11
# Current state:  371
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198614.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 11, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   11
# Current state:  411
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198615.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   12
# Current state:  451
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198616.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   11
# Current state:  452
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198617.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   10
# Current state:  451
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198618.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   9
# Current state:  450
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198619.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   10
# Current state:  449
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198620.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 12, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   10
# Current state:  450
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198621.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '12', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   11
# Current state:  490
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198622.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '12', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   12
# Current state:  491
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198623.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '12', 'y': 13}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   13
# Current state:  492
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198624.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '12', 'y': 14}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   14
# Current state:  493
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198625.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 11, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   14
# Current state:  494
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198626.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 10, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   14
# Current state:  454
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198627.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 11, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   14
# Current state:  414
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198628.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 15}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   15
# Current state:  454
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198629.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 14}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   14
# Current state:  455
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198630.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 10, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   14
# Current state:  454
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198631.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   14
# Current state:  414
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198632.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 10, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   14
# Current state:  374
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198633.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '10', 'y': 15}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   15
# Current state:  414
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198634.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '10', 'y': 14}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   14
# Current state:  415
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198635.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50292', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 11, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   14
# Current state:  414
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -198636.0

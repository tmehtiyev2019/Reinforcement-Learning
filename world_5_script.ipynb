# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=5
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1
        next_state_row, next_state_col=0,0

        while True:
            
            
            while True:


                if next_state_row==12 and next_state_col==18:
                    action=1
                    action = np.argmax(Q[world_id, state])


                # Choose action using epsilon-greedy strategy

    #             action = np.argmax(Q[world_id, state])
                elif random.uniform(0, 1) <= adjusted_epsilon:
                    if next_state_row != 12:
                        if next_state_row<12:
                            action=2
                        elif next_state_row>12:
                            action=3


                elif next_state_col!=18:
                    if next_state_col<18:
                        action=0
                    elif next_state_col>18:
                        action=1     
    #             elif:
    #                 state_row==20 and state_col==30:
    #                 action=1
    #                 action = np.argmax(Q[world_id, state])

                if Q[world_id, state, action]!= np.argmin(Q[world_id, state]) or Q[world_id, state, action]==0:
                    break

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.   3.   2.   2. 186.   7. 147.   2.   2.   2.   2.]
# 5  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381117.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381118.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381119.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381120.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381121.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': 4, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   2
# Current state:  122
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381122.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': '4', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   3
# Current state:  162
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381123.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': 3, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   3
# Current state:  163
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381124.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.43, 'newState': {'x': 4, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   3
# Current state:  123
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381125.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.39, 'newState': {'x': 3, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   3
# Current state:  163
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381126.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.35, 'newState': {'x': 4, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   3
# Current state:  123
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381127.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.31, 'newState': {'x': '4', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   4
# Current state:  163
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381128.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.28, 'newState': {'x': '4', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   5
# Current state:  164
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381129.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.25, 'newState': {'x': 5, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   5
# Current state:  165
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381130.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.23, 'newState': {'x': '5', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   6
# Current state:  205
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381131.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.21, 'newState': {'x': '5', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   7
# Current state:  206
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381132.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.19, 'newState': {'x': '5', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   8
# Current state:  207
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381133.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.17, 'newState': {'x': '5', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   9
# Current state:  208
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381134.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.15, 'newState': {'x': 6, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   9
# Current state:  209
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381135.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.14, 'newState': {'x': '6', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   10
# Current state:  249
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381136.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.12, 'newState': {'x': '6', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   11
# Current state:  250
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381137.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.11, 'newState': {'x': 7, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   11
# Current state:  251
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381138.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.1, 'newState': {'x': '7', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   12
# Current state:  291
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381139.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.09, 'newState': {'x': '7', 'y': 13}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   13
# Current state:  292
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381140.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.08, 'newState': {'x': '7', 'y': 14}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   14
# Current state:  293
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381141.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.07, 'newState': {'x': 8, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   14
# Current state:  294
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381142.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': 9, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   14
# Current state:  334
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381143.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': '9', 'y': 15}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   15
# Current state:  374
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381144.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '9', 'y': 16}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   16
# Current state:  375
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381145.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '9', 'y': 17}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   17
# Current state:  376
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381146.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': 10, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   17
# Current state:  377
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381147.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': 11, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   17
# Current state:  417
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381148.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '11', 'y': 18}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   18
# Current state:  457
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381149.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '11', 'y': 17}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   17
# Current state:  458
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381150.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 12, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   17
# Current state:  457
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381151.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '12', 'y': 18}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   18
# Current state:  497
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -381152.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': 10000, 'scoreIncrement': 225.28, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 5, 'runId': '50811', 'reward': 10000, 'scoreIncrement': 225.28, 'newState': None}
# 5  ended
# [  0.   3.   2.   2. 186.   8. 147.   2.   2.   2.   2.]
# 5  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371153.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371154.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371155.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   3
# Current state:  3
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371156.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': 2, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   3
# Current state:  43
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371157.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': '2', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   4
# Current state:  83
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371158.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': '2', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   5
# Current state:  84
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371159.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': '2', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   6
# Current state:  85
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371160.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.43, 'newState': {'x': '2', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   7
# Current state:  86
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371161.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.39, 'newState': {'x': 3, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   7
# Current state:  87
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371162.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.35, 'newState': {'x': 4, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   7
# Current state:  127
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371163.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.31, 'newState': {'x': '4', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   8
# Current state:  167
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371164.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.28, 'newState': {'x': 5, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   8
# Current state:  168
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371165.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.25, 'newState': {'x': 6, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   8
# Current state:  208
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371166.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.23, 'newState': {'x': '6', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   9
# Current state:  248
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371167.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.21, 'newState': {'x': 5, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   9
# Current state:  249
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371168.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.19, 'newState': {'x': 6, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   9
# Current state:  209
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371169.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.17, 'newState': {'x': '6', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   10
# Current state:  249
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371170.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.15, 'newState': {'x': 7, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   10
# Current state:  250
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371171.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.14, 'newState': {'x': 8, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   10
# Current state:  290
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371172.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.12, 'newState': {'x': '8', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   11
# Current state:  330
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371173.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.11, 'newState': {'x': '8', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   12
# Current state:  331
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371174.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.1, 'newState': {'x': '8', 'y': 13}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   13
# Current state:  332
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371175.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.09, 'newState': {'x': '8', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   12
# Current state:  333
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371176.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.08, 'newState': {'x': '8', 'y': 13}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   13
# Current state:  332
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371177.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.07, 'newState': {'x': 9, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   13
# Current state:  333
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371178.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': '9', 'y': 14}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   14
# Current state:  373
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371179.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': 10, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   14
# Current state:  374
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371180.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': 9, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   14
# Current state:  414
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371181.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': 10, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   14
# Current state:  374
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371182.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': 11, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   14
# Current state:  414
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371183.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '11', 'y': 15}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   15
# Current state:  454
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371184.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 12, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   15
# Current state:  455
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371185.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 13, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  13   15
# Current state:  495
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371186.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 12, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   15
# Current state:  535
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371187.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 11, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   15
# Current state:  495
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371188.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '11', 'y': 16}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   16
# Current state:  455
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371189.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '11', 'y': 17}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   17
# Current state:  456
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371190.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': 12, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   17
# Current state:  457
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371191.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '12', 'y': 18}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   18
# Current state:  497
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -371192.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': 10000, 'scoreIncrement': 147.81, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 5, 'runId': '50812', 'reward': 10000, 'scoreIncrement': 147.81, 'newState': None}
# 5  ended
# [  0.   3.   2.   2. 186.   9. 147.   2.   2.   2.   2.]
# 5  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361193.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361194.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361195.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361196.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': '0', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   4
# Current state:  3
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361197.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': '0', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   5
# Current state:  4
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361198.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': 1, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   5
# Current state:  5
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361199.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': '1', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   6
# Current state:  45
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361200.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.43, 'newState': {'x': 2, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   6
# Current state:  46
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361201.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.39, 'newState': {'x': '2', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   7
# Current state:  86
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361202.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.35, 'newState': {'x': 3, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   7
# Current state:  87
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361203.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.31, 'newState': {'x': 4, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   7
# Current state:  127
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361204.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.28, 'newState': {'x': 5, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   7
# Current state:  167
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361205.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.25, 'newState': {'x': 4, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   7
# Current state:  207
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361206.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.23, 'newState': {'x': '4', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   8
# Current state:  167
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361207.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.21, 'newState': {'x': '4', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   9
# Current state:  168
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361208.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.19, 'newState': {'x': '4', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   10
# Current state:  169
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361209.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.17, 'newState': {'x': 3, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   10
# Current state:  170
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361210.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.15, 'newState': {'x': 4, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   10
# Current state:  130
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361211.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.14, 'newState': {'x': '4', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   11
# Current state:  170
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361212.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.12, 'newState': {'x': 5, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   11
# Current state:  171
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361213.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.11, 'newState': {'x': 6, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   11
# Current state:  211
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361214.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.1, 'newState': {'x': '6', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   12
# Current state:  251
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361215.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.09, 'newState': {'x': 7, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   12
# Current state:  252
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361216.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.08, 'newState': {'x': '7', 'y': 13}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   13
# Current state:  292
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361217.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.07, 'newState': {'x': 8, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   13
# Current state:  293
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361218.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': 9, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   13
# Current state:  333
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361219.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': '9', 'y': 14}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   14
# Current state:  373
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361220.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '9', 'y': 15}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   15
# Current state:  374
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361221.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': 10, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   15
# Current state:  375
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361222.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '10', 'y': 16}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   16
# Current state:  415
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361223.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': 11, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   16
# Current state:  416
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361224.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '11', 'y': 17}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   17
# Current state:  456
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361225.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '11', 'y': 18}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   18
# Current state:  457
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361226.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 12, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   18
# Current state:  458
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -361227.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50813', 'reward': 10000, 'scoreIncrement': 250.32, 'newState': None}
# test except
# ...
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   4
# Current state:  124
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122248.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.43, 'newState': {'x': 5, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   4
# Current state:  164
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122249.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.39, 'newState': {'x': '5', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   5
# Current state:  204
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122250.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.35, 'newState': {'x': '5', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   6
# Current state:  205
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122251.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.31, 'newState': {'x': 6, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   6
# Current state:  206
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122252.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.28, 'newState': {'x': '6', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   7
# Current state:  246
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122253.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.25, 'newState': {'x': '6', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   8
# Current state:  247
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122254.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.23, 'newState': {'x': '6', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   9
# Current state:  248
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122255.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.21, 'newState': {'x': '6', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   10
# Current state:  249
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122256.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.19, 'newState': {'x': 7, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   10
# Current state:  250
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122257.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.17, 'newState': {'x': '7', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   9
# Current state:  290
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122258.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.15, 'newState': {'x': 8, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   9
# Current state:  289
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122259.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.14, 'newState': {'x': 9, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   9
# Current state:  329
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122260.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.12, 'newState': {'x': '9', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   10
# Current state:  369
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122261.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.11, 'newState': {'x': 10, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   10
# Current state:  370
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122262.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.1, 'newState': {'x': '10', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   11
# Current state:  410
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122263.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.09, 'newState': {'x': '10', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   10
# Current state:  411
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122264.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.08, 'newState': {'x': '10', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   11
# Current state:  410
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122265.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.07, 'newState': {'x': 11, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   11
# Current state:  411
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122266.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': 10, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   11
# Current state:  451
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122267.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': 11, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   11
# Current state:  411
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122268.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': 12, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   11
# Current state:  451
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122269.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '12', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   10
# Current state:  491
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122270.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '12', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   11
# Current state:  490
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122271.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '12', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   12
# Current state:  491
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122272.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '12', 'y': 13}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   13
# Current state:  492
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122273.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '12', 'y': 14}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   14
# Current state:  493
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122274.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '12', 'y': 15}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   15
# Current state:  494
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122275.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '12', 'y': 16}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   16
# Current state:  495
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122276.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '12', 'y': 17}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   17
# Current state:  496
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122277.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': 13, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  13   17
# Current state:  497
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122278.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '13', 'y': 18}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  13   18
# Current state:  537
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122279.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '13', 'y': 19}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  13   19
# Current state:  538
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122280.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 12, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   19
# Current state:  539
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122281.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '12', 'y': 18}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   18
# Current state:  499
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -122282.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': 10000, 'scoreIncrement': 119.73, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 5, 'runId': '50841', 'reward': 10000, 'scoreIncrement': 119.73, 'newState': None}
# 5  ended
# [  0.   3.   2.   2. 186.  34. 147.   2.   2.   2.   2.]
# 5  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50842', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -112283.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50842', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -112284.0

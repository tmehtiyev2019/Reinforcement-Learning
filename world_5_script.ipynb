# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=5
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1

        while True:
            
            
            # Choose action using epsilon-greedy strategy
            
#             action = np.argmax(Q[world_id, state])
            if random.uniform(0, 1) <= adjusted_epsilon:
                if state_row!=12:
                    if state_row<12:
                        action=2
                    elif state_row>12:
                        action=3
                        

            else:
                if state_col!=18:
                    if state_col<18:
                        action=0
                    elif state_col>18:
                        action=1     
            if state_row==12 and state_col==18:
                action=0
        

                action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.   3.   2.   2. 186.   6.   2.   2.   2.   2.   2.]
# 5  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389174.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389175.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389176.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389177.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389178.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': '3', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   2
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389179.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': '3', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   3
# Current state:  122
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389180.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': '3', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   4
# Current state:  123
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389181.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.43, 'newState': {'x': '3', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   5
# Current state:  124
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389182.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.39, 'newState': {'x': '3', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   6
# Current state:  125
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389183.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.35, 'newState': {'x': '3', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   5
# Current state:  126
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389184.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.31, 'newState': {'x': 4, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   5
# Current state:  125
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389185.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.28, 'newState': {'x': 5, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   5
# Current state:  165
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389186.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.25, 'newState': {'x': 4, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   5
# Current state:  205
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389187.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.23, 'newState': {'x': 5, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   5
# Current state:  165
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389188.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.21, 'newState': {'x': 6, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   5
# Current state:  205
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389189.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.19, 'newState': {'x': 7, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   5
# Current state:  245
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389190.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.17, 'newState': {'x': 8, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   5
# Current state:  285
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389191.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.15, 'newState': {'x': 7, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   5
# Current state:  325
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389192.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.14, 'newState': {'x': 8, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   5
# Current state:  285
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389193.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.12, 'newState': {'x': 9, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   5
# Current state:  325
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389194.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.11, 'newState': {'x': '9', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   6
# Current state:  365
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389195.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.1, 'newState': {'x': '9', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   7
# Current state:  366
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389196.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.09, 'newState': {'x': '9', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   8
# Current state:  367
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389197.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.08, 'newState': {'x': 10, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   8
# Current state:  368
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389198.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.07, 'newState': {'x': '10', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   9
# Current state:  408
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389199.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': '10', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   10
# Current state:  409
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389200.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': '10', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   11
# Current state:  410
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389201.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': 11, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   11
# Current state:  411
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389202.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': 12, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   11
# Current state:  451
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389203.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '12', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   12
# Current state:  491
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389204.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '12', 'y': 13}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   13
# Current state:  492
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389205.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '12', 'y': 14}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   14
# Current state:  493
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389206.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '12', 'y': 15}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   15
# Current state:  494
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389207.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '12', 'y': 16}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   16
# Current state:  495
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389208.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '12', 'y': 17}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   17
# Current state:  496
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389209.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': 11, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   17
# Current state:  497
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389210.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '11', 'y': 18}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   18
# Current state:  457
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389211.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': 12, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   18
# Current state:  458
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389212.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': 10000, 'scoreIncrement': 164.23, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 5, 'runId': '50310', 'reward': 10000, 'scoreIncrement': 164.23, 'newState': None}
# 5  ended
# [  0.   3.   2.   2. 186.   7.   2.   2.   2.   2.   2.]
# 5  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379213.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379214.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379215.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   3
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379216.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379217.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': '1', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   5
# Current state:  44
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379218.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': 0, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   5
# Current state:  45
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379219.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': '0', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   6
# Current state:  5
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379220.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.43, 'newState': {'x': 1, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   6
# Current state:  6
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379221.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.39, 'newState': {'x': 2, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   6
# Current state:  46
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379222.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.35, 'newState': {'x': 3, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   6
# Current state:  86
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379223.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.31, 'newState': {'x': 4, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   6
# Current state:  126
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379224.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.28, 'newState': {'x': '4', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   7
# Current state:  166
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379225.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.25, 'newState': {'x': 5, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   7
# Current state:  167
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379226.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.23, 'newState': {'x': '5', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   6
# Current state:  207
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379227.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.21, 'newState': {'x': 6, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   6
# Current state:  206
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379228.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.19, 'newState': {'x': '6', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   7
# Current state:  246
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379229.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.17, 'newState': {'x': '6', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   8
# Current state:  247
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379230.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.15, 'newState': {'x': '6', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   9
# Current state:  248
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379231.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.14, 'newState': {'x': '6', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   10
# Current state:  249
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379232.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.12, 'newState': {'x': '6', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   11
# Current state:  250
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379233.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.11, 'newState': {'x': '6', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   12
# Current state:  251
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379234.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.1, 'newState': {'x': '6', 'y': 13}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   13
# Current state:  252
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379235.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.09, 'newState': {'x': '6', 'y': 14}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   14
# Current state:  253
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379236.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.08, 'newState': {'x': 7, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   14
# Current state:  254
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379237.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.07, 'newState': {'x': 8, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   14
# Current state:  294
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379238.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': '8', 'y': 15}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   15
# Current state:  334
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379239.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': '8', 'y': 16}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   16
# Current state:  335
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379240.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '8', 'y': 17}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   17
# Current state:  336
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379241.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': 9, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   17
# Current state:  337
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379242.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': '9', 'y': 18}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   18
# Current state:  377
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379243.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': 10, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   18
# Current state:  378
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379244.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '10', 'y': 19}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   19
# Current state:  418
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379245.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 9, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   19
# Current state:  419
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379246.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '9', 'y': 20}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   20
# Current state:  379
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379247.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '9', 'y': 21}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   21
# Current state:  380
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379248.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': 10, 'y': '21'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   21
# Current state:  381
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379249.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': 11, 'y': '21'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   21
# Current state:  421
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379250.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '11', 'y': 22}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   22
# Current state:  461
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379251.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': 12, 'y': '22'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   22
# Current state:  462
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379252.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 11, 'y': '22'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   22
# Current state:  502
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379253.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 10, 'y': '22'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   22
# Current state:  462
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379254.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '10', 'y': 23}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   23
# Current state:  422
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379255.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '10', 'y': 24}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   24
# Current state:  423
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379256.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '10', 'y': 25}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   25
# Current state:  424
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379257.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '10', 'y': 26}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   26
# Current state:  425
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379258.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 11, 'y': '26'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   26
# Current state:  426
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379259.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '11', 'y': 27}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   27
# Current state:  466
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379260.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '11', 'y': 28}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   28
# Current state:  467
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379261.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 12, 'y': '28'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   28
# Current state:  468
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379262.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '12', 'y': 29}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   29
# Current state:  508
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379263.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '12', 'y': 30}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   30
# Current state:  509
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379264.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 11, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   30
# Current state:  510
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379265.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 31}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   31
# Current state:  470
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379266.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 32}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   32
# Current state:  471
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379267.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 33}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   33
# Current state:  472
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379268.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '11', 'y': 34}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   34
# Current state:  473
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379269.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 12, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   34
# Current state:  474
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379270.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 13, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  13   34
# Current state:  514
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379271.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '13', 'y': 35}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  13   35
# Current state:  554
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379272.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 14, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   35
# Current state:  555
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379273.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 36}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   36
# Current state:  595
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379274.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 35}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   35
# Current state:  596
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379275.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 36}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   36
# Current state:  595
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379276.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 35}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   35
# Current state:  596
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379277.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 36}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   36
# Current state:  595
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379278.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 37}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   37
# Current state:  596
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379279.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 38}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   38
# Current state:  597
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379280.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   39
# Current state:  598
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379281.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   39
# Current state:  599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379282.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   39
# Current state:  599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379283.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 15, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  15   39
# Current state:  599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379284.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '15', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  15   39
# Current state:  639
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379285.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 16, 'y': '39'}}
# ...
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379671.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379672.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379673.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379674.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379675.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379676.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379677.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379678.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379679.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379680.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379681.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 38}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   38
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379682.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   38
# Current state:  1598
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379683.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   38
# Current state:  1598
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379684.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1598
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379685.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379686.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379687.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379688.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379689.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379690.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379691.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379692.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379693.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379694.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379695.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379696.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379697.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379698.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379699.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379700.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379701.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 38}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   38
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379702.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   38
# Current state:  1598
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379703.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1598
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379704.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379705.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379706.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   39
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379707.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50313', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 38}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  39   38
# Current state:  1599
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -379708.0

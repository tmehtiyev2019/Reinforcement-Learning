# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 1000
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
#         if min(world_traversal_count[1:])<minimum_traversal_requirement:
#             world_id=np.argmin(world_traversal_count[1:])+1
#             print(world_traversal_count)
#         else:
#             world_id=np.argmax(score_map[1:])+1
#             print(score_map)

        world_id=10
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1
        next_state_row, next_state_col=0,0

        while True:
            while True:


                if next_state_row==3 and next_state_col==3:
                    action=1
                    action = np.argmax(Q[world_id, state])


                # Choose action using epsilon-greedy strategy

    #             action = np.argmax(Q[world_id, state])
                elif random.uniform(0, 1) <= adjusted_epsilon:
                    if next_state_row != 3:
                        if next_state_row<3:
                            action=2
                        elif next_state_row>3:
                            action=3


                elif next_state_col!=3:
                    if next_state_col<0:
                        action=0
                    elif next_state_col>3:
                        action=1  
                break
    #             elif:
    #                 state_row==20 and state_col==30:
    #                 action=1
    #                 action = np.argmax(Q[world_id, state])

#                 if Q[world_id, state, action]!= np.argmin(Q[world_id, state]) or Q[world_id, state, action]==0:
#                     break


#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52475', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2288875.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52475', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2288874.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52475', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2288873.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52475', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52475', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52476', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2298872.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52476', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2298871.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52476', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2298870.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52476', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52476', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52477', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2308869.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52477', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2308868.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52477', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2308867.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52477', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52477', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52478', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2318866.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52478', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2318865.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52478', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2318864.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52478', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52478', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52479', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2328863.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52479', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2328862.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52479', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2328861.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52479', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52479', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52480', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2338860.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52480', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2338859.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52480', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2338858.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52480', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52480', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52481', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2348857.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52481', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2348856.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52481', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2348855.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52481', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52481', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52482', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2358854.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52482', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2358853.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52482', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2358852.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52482', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52482', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52483', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2368851.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52483', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2368850.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52483', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2368849.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52483', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52483', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52484', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2378848.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52484', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2378847.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52484', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2378846.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52484', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52484', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52485', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2388845.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52485', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2388844.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52485', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2388843.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52485', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52485', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 1  episode started
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52486', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2398842.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52486', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2398841.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52486', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2398840.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52486', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52486', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52487', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2408839.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52487', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2408838.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52487', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2408837.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52487', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52487', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52488', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2418836.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52488', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2418835.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52488', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2418834.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52488', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52488', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52489', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2428833.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52489', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2428832.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52489', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2428831.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52489', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52489', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52490', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2438830.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52490', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2438829.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52490', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2438828.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52490', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52490', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52491', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2448827.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52491', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2448826.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52491', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2448825.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52491', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52491', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52492', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2458824.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52492', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2458823.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52492', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2458822.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52492', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52492', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52494', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2468821.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52494', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2468820.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52494', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2468819.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52494', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52494', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52495', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2478818.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52495', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2478817.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52495', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2478816.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52495', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52495', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52496', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2488815.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52496', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2488814.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52496', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2488813.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52496', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52496', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52497', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2498812.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52497', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2498811.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52497', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2498810.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52497', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52497', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 2  episode started
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52498', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2508809.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52498', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2508808.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52498', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2508807.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52498', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52498', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52499', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2518806.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52499', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2518805.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52499', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2518804.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52499', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52499', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52501', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2528803.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52501', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2528802.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52501', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2528801.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52501', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52501', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52502', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2538800.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52502', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2538799.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52502', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2538798.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52502', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52502', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52503', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2548797.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52503', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2548796.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52503', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2548795.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52503', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52503', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52504', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2558794.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52504', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2558793.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52504', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2558792.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52504', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52504', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52505', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2568791.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52505', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2568790.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52505', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# ...
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2838709.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52533', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2838708.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52533', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52533', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52534', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2848707.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52534', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2848706.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52534', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2848705.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52534', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52534', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52535', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2858704.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52535', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2858703.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52535', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2858702.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52535', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52535', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52537', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2868701.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52537', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2868700.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52537', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2868699.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52537', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52537', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52538', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2878698.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52538', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2878697.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52538', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2878696.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52538', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52538', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52539', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2888695.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52539', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2888694.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52539', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2888693.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52539', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52539', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52540', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2898692.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52540', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2898691.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52540', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2898690.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52540', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52540', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52541', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2908689.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52541', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2908688.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52541', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2908687.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52541', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52541', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52543', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2918686.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52543', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2918685.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52543', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2918684.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52543', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52543', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 10  ended
# 10  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52544', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2928683.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52544', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2928682.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52544', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  10
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  2928681.0
# printing the response:
#  {'code': 'OK', 'worldId': 10, 'runId': '52544', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 10, 'runId': '52544', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}

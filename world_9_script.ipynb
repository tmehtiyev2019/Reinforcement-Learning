# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 1000
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
#         if min(world_traversal_count[1:])<minimum_traversal_requirement:
#             world_id=np.argmin(world_traversal_count[1:])+1
#             print(world_traversal_count)
#         else:
#             world_id=np.argmax(score_map[1:])+1
#             print(score_map)

        world_id=9
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1
        next_state_row, next_state_col=0,0

        while True:
            while True:


                if next_state_row==3 and next_state_col==0:
                    action=1
                    action = np.argmax(Q[world_id, state])


                # Choose action using epsilon-greedy strategy

    #             action = np.argmax(Q[world_id, state])
                elif random.uniform(0, 1) <= adjusted_epsilon:
                    if next_state_row != 3:
                        if next_state_row<3:
                            action=2
                        elif next_state_row>3:
                            action=3


                elif next_state_col!=0:
                    if next_state_col<0:
                        action=0
                    elif next_state_col>0:
                        action=1  
                break
    #             elif:
    #                 state_row==20 and state_col==30:
    #                 action=1
    #                 action = np.argmax(Q[world_id, state])

#                 if Q[world_id, state, action]!= np.argmin(Q[world_id, state]) or Q[world_id, state, action]==0:
#                     break


#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52592', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1061018.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52592', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1061019.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52592', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1061020.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52592', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1061021.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52592', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1061022.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52592', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52592', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52594', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1071023.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52594', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1071024.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52594', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1071025.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52594', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1071026.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52594', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1071027.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52594', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1071028.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52594', 'reward': 10000, 'scoreIncrement': 5314.41, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52594', 'reward': 10000, 'scoreIncrement': 5314.41, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52595', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1081029.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52595', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1081030.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52595', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1081031.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52595', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1081032.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52595', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1081033.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52595', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52595', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091034.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091035.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091036.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091037.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091038.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091039.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091040.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091041.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091042.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 4, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  4   2
# Current state:  122
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091043.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '4', 'y': 3}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  4   3
# Current state:  162
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091044.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': 3, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   3
# Current state:  163
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1091045.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 10000, 'scoreIncrement': 2824.3, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52596', 'reward': 10000, 'scoreIncrement': 2824.3, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52597', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1101046.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52597', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1101047.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52597', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1101048.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52597', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52597', 'reward': 10000, 'scoreIncrement': 7290, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111049.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111050.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111051.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111052.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111053.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111054.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111055.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111056.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111057.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  42
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111058.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111059.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111060.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111061.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111062.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111063.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': '3', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  121
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1111064.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 10000, 'scoreIncrement': 1853.02, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52598', 'reward': 10000, 'scoreIncrement': 1853.02, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52599', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1121065.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52599', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1121066.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52599', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1121067.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52599', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1121068.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52599', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1121069.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52599', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1121070.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52599', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1121071.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52599', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '3', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  121
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1121072.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52599', 'reward': 10000, 'scoreIncrement': 4304.67, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52599', 'reward': 10000, 'scoreIncrement': 4304.67, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52600', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1131073.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52600', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1131074.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52600', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1131075.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52600', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1131076.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52600', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1131077.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52600', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1131078.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52600', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '3', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1131079.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52600', 'reward': 10000, 'scoreIncrement': 4782.97, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52600', 'reward': 10000, 'scoreIncrement': 4782.97, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52601', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1141080.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52601', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1141081.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52601', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1141082.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52601', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1141083.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52601', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1141084.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52601', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52601', 'reward': 10000, 'scoreIncrement': 5904.9, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151085.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151086.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151087.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151088.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151089.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151090.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151091.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151092.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151093.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151094.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151095.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151096.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151097.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151098.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151099.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151100.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151101.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  121
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151102.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151103.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151104.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151105.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151106.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1151107.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 10000, 'scoreIncrement': 886.29, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52602', 'reward': 10000, 'scoreIncrement': 886.29, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52604', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1161108.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52604', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1161109.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52604', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1161110.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52604', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1161111.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52604', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  4   1
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1161112.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52604', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  161
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1161113.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52604', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '3', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  121
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1161114.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52604', 'reward': 10000, 'scoreIncrement': 4782.97, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52604', 'reward': 10000, 'scoreIncrement': 4782.97, 'newState': None}
# 9  ended
# 1  episode started
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52605', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1171115.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52605', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1171116.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52605', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1171117.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52605', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1171118.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52605', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1171119.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52605', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1171120.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52605', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   2
# Current state:  2
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1171121.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52605', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '1', 'y': 1}}
# ...
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1361281.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52630', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1361282.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52630', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1361283.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52630', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1361284.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52630', 'reward': 10000, 'scoreIncrement': 3486.78, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52630', 'reward': 10000, 'scoreIncrement': 3486.78, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52631', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1371285.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52631', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1371286.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52631', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1371287.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52631', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1371288.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52631', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1371289.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52631', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1371290.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52631', 'reward': 10000, 'scoreIncrement': 5314.41, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52631', 'reward': 10000, 'scoreIncrement': 5314.41, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52632', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1381291.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52632', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1381292.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52632', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1381293.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52632', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1381294.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52632', 'reward': 10000, 'scoreIncrement': 6561, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52632', 'reward': 10000, 'scoreIncrement': 6561, 'newState': None}
# 9  ended
# 3  episode started
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1391295.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1391296.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1391297.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1391298.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1391299.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1391300.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1391301.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1391302.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1391303.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 10000, 'scoreIncrement': 3874.2, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52633', 'reward': 10000, 'scoreIncrement': 3874.2, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52634', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1401304.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52634', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1401305.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52634', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1401306.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52634', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1401307.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52634', 'reward': 10000, 'scoreIncrement': 6561, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52634', 'reward': 10000, 'scoreIncrement': 6561, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52635', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1411308.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52635', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1411309.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52635', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1411310.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52635', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1411311.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52635', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1411312.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52635', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  1411313.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '52635', 'reward': 10000, 'scoreIncrement': 5314.41, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '52635', 'reward': 10000, 'scoreIncrement': 5314.41, 'newState': None}
# 9  ended
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}

# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = 1
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=9
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1

        while True:
            
            
            
            
            # Choose action using epsilon-greedy strategy
            
#             action = np.argmax(Q[world_id, state])
            if random.uniform(0, 1) <= adjusted_epsilon:
#                 while True:
#                     a = random.randint(0, 3)
#                     if Q[world_id, state, a]!= np.argmin(Q[world_id, state]) or Q[world_id, state, a]==0:
#                         action=a
#                         break

        
                for a in range(n_actions):
                    if Q[world_id, state, a]==0:
                        action=a
                        break
                    else:
                        action = random.randint(0, 3)
#                         if Q[world_id, state, a]!= np.argmin(Q[world_id, state]):
#                             action=a
                        
#             else :
#                 action=np.argmax(Q[world_id, state])
                        
#                         while True:
#                             a = random.randint(0, 3)
#                             if Q[world_id, state, a]!= np.argmin(Q[world_id, state]):
#                                 action=a
#                                 break
                        

#             else:

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                print("Last action to terminal: ", action )
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        
        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        if reward>0:
            break
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# # Print the learned policy
# for world_id in range(n_worlds):
#     print(f"World {world_id}:")
#     for state in range(n_states):
#         print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.   2.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20041.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  40
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20042.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20043.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20044.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20045.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20046.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20047.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20048.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20049.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20050.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20051.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20052.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20053.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20054.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  1
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20055.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20056.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20057.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20058.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20059.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20060.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  20061.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 10000, 'scoreIncrement': 1094.19, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51897', 'reward': 10000, 'scoreIncrement': 1094.19, 'newState': None}
# Last action to terminal:  0
# 1  episode started
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.   3.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30062.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30063.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30064.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30065.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30066.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  121
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30067.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  81
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30068.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30069.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  42
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30070.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30071.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  2
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30072.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30073.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   3
# Current state:  3
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30074.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   2
# Current state:  43
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30075.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30076.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30077.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   2
# Current state:  122
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30078.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   2
# Current state:  82
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30079.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   3
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30080.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30081.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30082.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   4
# Current state:  4
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30083.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30084.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   3
# Current state:  4
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30085.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': '0', 'y': 4}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   4
# Current state:  3
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30086.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   3
# Current state:  4
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30087.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30088.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  3
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30089.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  2
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30090.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  1
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30091.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30092.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30093.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30094.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30095.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30096.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '2', 'y': 3}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   3
# Current state:  82
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30097.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   3
# Current state:  83
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30098.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30099.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': '1', 'y': 5}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   5
# Current state:  44
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30100.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': '1', 'y': 6}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   6
# Current state:  45
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30101.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '1', 'y': 7}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   7
# Current state:  46
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30102.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '1', 'y': 8}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   8
# Current state:  47
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30103.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '1', 'y': 9}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   9
# Current state:  48
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30104.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 0, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   9
# Current state:  49
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30105.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 1, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   9
# Current state:  9
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30106.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '1', 'y': 8}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   8
# Current state:  49
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30107.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 2, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   8
# Current state:  48
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30108.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 3, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   8
# Current state:  88
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30109.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '3', 'y': 7}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   7
# Current state:  128
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30110.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '3', 'y': 8}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   8
# Current state:  127
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30111.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '3', 'y': 7}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   7
# Current state:  128
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30112.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '3', 'y': 6}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  3   6
# Current state:  127
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  30113.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 10000, 'scoreIncrement': 41.75, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 9, 'runId': '51898', 'reward': 10000, 'scoreIncrement': 41.75, 'newState': None}
# Last action to terminal:  0
# 2  episode started
# [  0.  77.  17.  92. 186.  34. 147.  37.   9.   4.   2.]
# 9  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40114.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40115.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  1
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40116.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40117.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40118.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40119.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40120.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40121.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40122.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40123.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  80
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40124.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40125.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40126.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40127.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40128.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   2
# Current state:  82
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40129.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  42
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40130.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40131.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  3
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40132.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  2
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40133.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40134.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40135.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  42
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40136.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40137.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   2
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40138.0
# printing the response:
#  {'code': 'OK', 'worldId': 9, 'runId': '51901', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  9
# Current state row and column:  0   1
# Current state:  2
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  40139.0
# printing the response:
#  {'code': 'FAIL', 'message': 'Cannot make a move.  You are currently not in any world.  Otnicka, where are you?'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 191
#     188         time.sleep(10 * 60)
#     190 print("printing the response: \n", move_resp)
# --> 191 reward = float(move_resp["reward"])
#     192 reward_map[world_id]=reward_map[world_id]+reward
#     194 # Get the next state
#
# KeyError: 'reward'

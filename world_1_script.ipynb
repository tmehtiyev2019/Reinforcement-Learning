# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=1
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1
        next_state_row, next_state_col=0,0

        while True:
            while True:


                if next_state_row==24 and next_state_col==24:
                    action=1
                    action = np.argmax(Q[world_id, state])


                # Choose action using epsilon-greedy strategy

    #             action = np.argmax(Q[world_id, state])
                elif random.uniform(0, 1) <= adjusted_epsilon:
                    if next_state_row != 24:
                        if next_state_row<24:
                            action=2
                        elif next_state_row>24:
                            action=3


                elif next_state_col!=24:
                    if next_state_col<24:
                        action=0
                    elif next_state_col>24:
                        action=1     
    #             elif:
    #                 state_row==20 and state_col==30:
    #                 action=1
    #                 action = np.argmax(Q[world_id, state])

                if Q[world_id, state, action]!= np.argmin(Q[world_id, state]) or Q[world_id, state, action]==0:
                    break

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.   5.   2.   2. 186.  34. 147.  37.   9.   2.   2.]
# 1  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.1, 'scoreIncrement': 0.1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  13098.540000000308
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.11, 'scoreIncrement': 0.1, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  13098.650000000309
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.11, 'scoreIncrement': 0.09, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  13098.76000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.11, 'scoreIncrement': 0.08, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  13098.87000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.11, 'scoreIncrement': 0.07, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  13098.98000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.12, 'scoreIncrement': 0.07, 'newState': {'x': '3', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  3   3
# Current state:  122
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  13099.100000000311
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.12, 'scoreIncrement': 0.06, 'newState': {'x': '3', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  3   4
# Current state:  123
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  13099.220000000312
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.12, 'scoreIncrement': 0.06, 'newState': {'x': 4, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  4   4
# Current state:  124
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  13099.340000000313
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': '4', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  4   3
# Current state:  164
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  13099.460000000314
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': 5, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  5   3
# Current state:  163
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  13099.580000000315
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.13, 'scoreIncrement': 0.05, 'newState': {'x': 6, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   3
# Current state:  203
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  13099.710000000314
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.12, 'scoreIncrement': 0.04, 'newState': {'x': '6', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   2
# Current state:  243
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  13099.830000000315
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.13, 'scoreIncrement': 0.04, 'newState': {'x': '6', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   3
# Current state:  242
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  13099.960000000314
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.13, 'scoreIncrement': 0.03, 'newState': {'x': 7, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   3
# Current state:  243
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  13100.090000000313
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.13, 'scoreIncrement': 0.03, 'newState': {'x': '7', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   4
# Current state:  283
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  13100.220000000312
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.14, 'scoreIncrement': 0.03, 'newState': {'x': '7', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   5
# Current state:  284
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  13100.360000000312
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.14, 'scoreIncrement': 0.03, 'newState': {'x': '7', 'y': 6}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   6
# Current state:  285
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  13100.500000000311
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.14, 'scoreIncrement': 0.02, 'newState': {'x': '7', 'y': 7}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   7
# Current state:  286
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  13100.64000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.15, 'scoreIncrement': 0.02, 'newState': {'x': 8, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  8   7
# Current state:  287
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  13100.79000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.15, 'scoreIncrement': 0.02, 'newState': {'x': '8', 'y': 8}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  8   8
# Current state:  327
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  13100.94000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.16, 'scoreIncrement': 0.02, 'newState': {'x': 9, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  9   8
# Current state:  328
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  13101.10000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.16, 'scoreIncrement': 0.02, 'newState': {'x': 10, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  10   8
# Current state:  368
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  13101.26000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.17, 'scoreIncrement': 0.02, 'newState': {'x': 11, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   8
# Current state:  408
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  13101.43000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.17, 'scoreIncrement': 0.02, 'newState': {'x': '11', 'y': 9}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   9
# Current state:  448
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.17
# cumulative reward from the world so far:  13101.60000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.18, 'scoreIncrement': 0.01, 'newState': {'x': '11', 'y': 10}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   10
# Current state:  449
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.18
# cumulative reward from the world so far:  13101.78000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': '11', 'y': 11}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   11
# Current state:  450
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  13101.97000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': 12, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   11
# Current state:  451
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  13102.16000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.2, 'scoreIncrement': 0.01, 'newState': {'x': '12', 'y': 12}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   12
# Current state:  491
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.2
# cumulative reward from the world so far:  13102.360000000312
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.21, 'scoreIncrement': 0.01, 'newState': {'x': '12', 'y': 13}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   13
# Current state:  492
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.21
# cumulative reward from the world so far:  13102.57000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.22, 'scoreIncrement': 0.01, 'newState': {'x': '12', 'y': 14}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   14
# Current state:  493
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  13102.79000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.23, 'scoreIncrement': 0.01, 'newState': {'x': '12', 'y': 15}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   15
# Current state:  494
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.23
# cumulative reward from the world so far:  13103.02000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.24, 'scoreIncrement': 0.01, 'newState': {'x': '12', 'y': 16}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   16
# Current state:  495
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.24
# cumulative reward from the world so far:  13103.26000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.25, 'scoreIncrement': 0.01, 'newState': {'x': 13, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  13   16
# Current state:  496
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.25
# cumulative reward from the world so far:  13103.51000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.26, 'scoreIncrement': 0.01, 'newState': {'x': 14, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  14   16
# Current state:  536
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.26
# cumulative reward from the world so far:  13103.77000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.28, 'scoreIncrement': 0.01, 'newState': {'x': '14', 'y': 17}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  14   17
# Current state:  576
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.28
# cumulative reward from the world so far:  13104.05000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.29, 'scoreIncrement': 0.01, 'newState': {'x': '14', 'y': 18}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  14   18
# Current state:  577
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.29
# cumulative reward from the world so far:  13104.340000000311
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.31, 'scoreIncrement': 0.01, 'newState': {'x': 15, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  15   18
# Current state:  578
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.31
# cumulative reward from the world so far:  13104.65000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.33, 'scoreIncrement': 0.01, 'newState': {'x': '15', 'y': 19}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  15   19
# Current state:  618
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.33
# cumulative reward from the world so far:  13104.98000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.31, 'scoreIncrement': 0.01, 'newState': {'x': 14, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  14   19
# Current state:  619
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.31
# cumulative reward from the world so far:  13105.29000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.33, 'scoreIncrement': 0.01, 'newState': {'x': 15, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  15   19
# Current state:  579
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.33
# cumulative reward from the world so far:  13105.62000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.36, 'scoreIncrement': 0.01, 'newState': {'x': 16, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  16   19
# Current state:  619
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.36
# cumulative reward from the world so far:  13105.98000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.38, 'scoreIncrement': 0.01, 'newState': {'x': '16', 'y': 20}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  16   20
# Current state:  659
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.38
# cumulative reward from the world so far:  13106.36000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.42, 'scoreIncrement': 0.01, 'newState': {'x': 17, 'y': '20'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   20
# Current state:  660
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.42
# cumulative reward from the world so far:  13106.78000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': 18, 'y': '20'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  18   20
# Current state:  700
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.45
# cumulative reward from the world so far:  13107.23000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': 19, 'y': '20'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  19   20
# Current state:  740
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.5
# cumulative reward from the world so far:  13107.73000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': 20, 'y': '20'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  20   20
# Current state:  780
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.56
# cumulative reward from the world so far:  13108.29000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': 21, 'y': '20'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  21   20
# Current state:  820
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.63
# cumulative reward from the world so far:  13108.92000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.71, 'scoreIncrement': 0.01, 'newState': {'x': 22, 'y': '20'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  22   20
# Current state:  860
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.71
# cumulative reward from the world so far:  13109.630000000308
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 0.83, 'scoreIncrement': 0.01, 'newState': {'x': '22', 'y': 21}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  22   21
# Current state:  900
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.83
# cumulative reward from the world so far:  13110.460000000308
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 23, 'y': '21'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  23   21
# Current state:  901
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  13111.460000000308
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 1.25, 'scoreIncrement': 0.01, 'newState': {'x': '23', 'y': 22}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  23   22
# Current state:  941
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.25
# cumulative reward from the world so far:  13112.710000000308
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 1.67, 'scoreIncrement': 0.01, 'newState': {'x': 24, 'y': '22'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   22
# Current state:  942
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.67
# cumulative reward from the world so far:  13114.380000000308
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 2.5, 'scoreIncrement': 0.01, 'newState': {'x': '24', 'y': 23}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   23
# Current state:  982
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  2.5
# cumulative reward from the world so far:  13116.880000000308
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 1.67, 'scoreIncrement': 0.01, 'newState': {'x': '24', 'y': 22}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   22
# Current state:  983
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.67
# cumulative reward from the world so far:  13118.550000000309
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 2.5, 'scoreIncrement': 0.01, 'newState': {'x': '24', 'y': 23}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   23
# Current state:  982
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  2.5
# cumulative reward from the world so far:  13121.050000000309
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 5, 'scoreIncrement': 0.02, 'newState': {'x': '24', 'y': 24}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   24
# Current state:  983
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  5.0
# cumulative reward from the world so far:  13126.050000000309
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 10000, 'scoreIncrement': 27.39, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 1, 'runId': '51258', 'reward': 10000, 'scoreIncrement': 27.39, 'newState': None}
# 1  ended
# [  0.   6.   2.   2. 186.  34. 147.  37.   9.   2.   2.]
# 1  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.1, 'scoreIncrement': 0.1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.1
# cumulative reward from the world so far:  23126.150000000307
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.11, 'scoreIncrement': 0.1, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  23126.260000000308
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.11, 'scoreIncrement': 0.09, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   2
# Current state:  2
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  23126.37000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.11, 'scoreIncrement': 0.08, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  23126.48000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.11, 'scoreIncrement': 0.07, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  23126.59000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.12, 'scoreIncrement': 0.07, 'newState': {'x': '3', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  3   3
# Current state:  122
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  23126.71000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.12, 'scoreIncrement': 0.06, 'newState': {'x': 4, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  4   3
# Current state:  123
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  23126.830000000307
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.12, 'scoreIncrement': 0.06, 'newState': {'x': 5, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  5   3
# Current state:  163
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  23126.950000000306
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': '5', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  5   2
# Current state:  203
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  23127.070000000305
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': 6, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   2
# Current state:  202
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  23127.190000000304
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.13, 'scoreIncrement': 0.05, 'newState': {'x': 7, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   2
# Current state:  242
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  23127.320000000305
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.13, 'scoreIncrement': 0.04, 'newState': {'x': 8, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  8   2
# Current state:  282
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  23127.450000000306
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.13, 'scoreIncrement': 0.04, 'newState': {'x': 9, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  9   2
# Current state:  322
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  23127.580000000307
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.14, 'scoreIncrement': 0.04, 'newState': {'x': '9', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  9   3
# Current state:  362
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  23127.720000000307
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.14, 'scoreIncrement': 0.03, 'newState': {'x': '9', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  9   4
# Current state:  363
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  23127.860000000306
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.14, 'scoreIncrement': 0.03, 'newState': {'x': 10, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  10   4
# Current state:  364
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  23128.000000000306
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.15, 'scoreIncrement': 0.03, 'newState': {'x': 11, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   4
# Current state:  404
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  23128.150000000307
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.15, 'scoreIncrement': 0.03, 'newState': {'x': 12, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   4
# Current state:  444
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  23128.30000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.16, 'scoreIncrement': 0.02, 'newState': {'x': 13, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  13   4
# Current state:  484
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  23128.46000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.16, 'scoreIncrement': 0.02, 'newState': {'x': '13', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  13   5
# Current state:  524
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  23128.62000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.17, 'scoreIncrement': 0.02, 'newState': {'x': '13', 'y': 6}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  13   6
# Current state:  525
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  23128.790000000306
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.17, 'scoreIncrement': 0.02, 'newState': {'x': 14, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  14   6
# Current state:  526
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  23128.960000000305
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.18, 'scoreIncrement': 0.02, 'newState': {'x': 15, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  15   6
# Current state:  566
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.18
# cumulative reward from the world so far:  23129.140000000305
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.17, 'scoreIncrement': 0.02, 'newState': {'x': '15', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  15   5
# Current state:  606
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  23129.310000000303
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.18, 'scoreIncrement': 0.01, 'newState': {'x': 16, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  16   5
# Current state:  605
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.18
# cumulative reward from the world so far:  23129.490000000304
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': '16', 'y': 6}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  16   6
# Current state:  645
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  23129.680000000302
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': '16', 'y': 7}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  16   7
# Current state:  646
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  23129.8700000003
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.2, 'scoreIncrement': 0.01, 'newState': {'x': '16', 'y': 8}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  16   8
# Current state:  647
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.2
# cumulative reward from the world so far:  23130.0700000003
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.21, 'scoreIncrement': 0.01, 'newState': {'x': 17, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   8
# Current state:  648
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.21
# cumulative reward from the world so far:  23130.2800000003
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.22, 'scoreIncrement': 0.01, 'newState': {'x': '17', 'y': 9}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   9
# Current state:  688
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  23130.500000000302
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.21, 'scoreIncrement': 0.01, 'newState': {'x': 16, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  16   9
# Current state:  689
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.21
# cumulative reward from the world so far:  23130.7100000003
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.22, 'scoreIncrement': 0.01, 'newState': {'x': '16', 'y': 10}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  16   10
# Current state:  649
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  23130.930000000302
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.23, 'scoreIncrement': 0.01, 'newState': {'x': 17, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   10
# Current state:  650
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.23
# cumulative reward from the world so far:  23131.1600000003
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.24, 'scoreIncrement': 0.01, 'newState': {'x': 18, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  18   10
# Current state:  690
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.24
# cumulative reward from the world so far:  23131.400000000303
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.25, 'scoreIncrement': 0.01, 'newState': {'x': '18', 'y': 11}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  18   11
# Current state:  730
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.25
# cumulative reward from the world so far:  23131.650000000303
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.26, 'scoreIncrement': 0.01, 'newState': {'x': '18', 'y': 12}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  18   12
# Current state:  731
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.26
# cumulative reward from the world so far:  23131.9100000003
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.28, 'scoreIncrement': 0.01, 'newState': {'x': 19, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  19   12
# Current state:  732
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.28
# cumulative reward from the world so far:  23132.1900000003
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.29, 'scoreIncrement': 0.01, 'newState': {'x': 20, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  20   12
# Current state:  772
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.29
# cumulative reward from the world so far:  23132.4800000003
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.31, 'scoreIncrement': 0.01, 'newState': {'x': 21, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  21   12
# Current state:  812
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.31
# cumulative reward from the world so far:  23132.790000000303
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.33, 'scoreIncrement': 0.01, 'newState': {'x': '21', 'y': 13}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  21   13
# Current state:  852
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.33
# cumulative reward from the world so far:  23133.120000000305
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.36, 'scoreIncrement': 0.01, 'newState': {'x': 22, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  22   13
# Current state:  853
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.36
# cumulative reward from the world so far:  23133.480000000305
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.38, 'scoreIncrement': 0.01, 'newState': {'x': '22', 'y': 14}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  22   14
# Current state:  893
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.38
# cumulative reward from the world so far:  23133.860000000306
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.42, 'scoreIncrement': 0.01, 'newState': {'x': '22', 'y': 15}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  22   15
# Current state:  894
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.42
# cumulative reward from the world so far:  23134.280000000304
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 16}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  22   16
# Current state:  895
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.45
# cumulative reward from the world so far:  23134.730000000305
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': 23, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  23   16
# Current state:  896
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.5
# cumulative reward from the world so far:  23135.230000000305
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': '23', 'y': 17}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  23   17
# Current state:  936
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.56
# cumulative reward from the world so far:  23135.790000000306
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': '23', 'y': 18}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  23   18
# Current state:  937
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.63
# cumulative reward from the world so far:  23136.420000000307
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.71, 'scoreIncrement': 0.01, 'newState': {'x': 24, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   18
# Current state:  938
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.71
# cumulative reward from the world so far:  23137.130000000307
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 0.83, 'scoreIncrement': 0.01, 'newState': {'x': '24', 'y': 19}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   19
# Current state:  978
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  23137.96000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '24', 'y': 20}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   20
# Current state:  979
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  23138.96000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 1.25, 'scoreIncrement': 0.01, 'newState': {'x': '24', 'y': 21}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   21
# Current state:  980
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.25
# cumulative reward from the world so far:  23140.21000000031
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 1.67, 'scoreIncrement': 0.01, 'newState': {'x': '24', 'y': 22}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   22
# Current state:  981
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.67
# cumulative reward from the world so far:  23141.880000000307
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 2.5, 'scoreIncrement': 0.01, 'newState': {'x': '24', 'y': 23}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   23
# Current state:  982
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  2.5
# cumulative reward from the world so far:  23144.380000000307
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51259', 'reward': 5, 'scoreIncrement': 0.02, 'newState': {'x': '24', 'y': 24}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  24   24
# Current state:  983
# Taken action to come to the current state from the previous state:  0
# ...
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.12, 'scoreIncrement': 0.06, 'newState': {'x': 6, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   0
# Current state:  200
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  123667.02000000024
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': '6', 'y': 1}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   1
# Current state:  240
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  123667.14000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': '6', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  6   2
# Current state:  241
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  123667.26000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.13, 'scoreIncrement': 0.05, 'newState': {'x': 7, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   2
# Current state:  242
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  123667.39000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.13, 'scoreIncrement': 0.04, 'newState': {'x': '7', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  7   3
# Current state:  282
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  123667.52000000024
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.13, 'scoreIncrement': 0.04, 'newState': {'x': 8, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  8   3
# Current state:  283
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  123667.65000000024
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.14, 'scoreIncrement': 0.04, 'newState': {'x': '8', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  8   4
# Current state:  323
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  123667.79000000024
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.14, 'scoreIncrement': 0.03, 'newState': {'x': 9, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  9   4
# Current state:  324
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  123667.93000000024
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.14, 'scoreIncrement': 0.03, 'newState': {'x': 10, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  10   4
# Current state:  364
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  123668.07000000024
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.15, 'scoreIncrement': 0.03, 'newState': {'x': 11, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   4
# Current state:  404
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  123668.22000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.14, 'scoreIncrement': 0.02, 'newState': {'x': '11', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   3
# Current state:  444
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  123668.36000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.15, 'scoreIncrement': 0.02, 'newState': {'x': '11', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  11   4
# Current state:  443
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  123668.51000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.15, 'scoreIncrement': 0.02, 'newState': {'x': 12, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   4
# Current state:  444
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  123668.66000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.16, 'scoreIncrement': 0.02, 'newState': {'x': '12', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   5
# Current state:  484
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  123668.82000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.16, 'scoreIncrement': 0.02, 'newState': {'x': '12', 'y': 6}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   6
# Current state:  485
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  123668.98000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.17, 'scoreIncrement': 0.02, 'newState': {'x': '12', 'y': 7}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  12   7
# Current state:  486
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  123669.15000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.17, 'scoreIncrement': 0.02, 'newState': {'x': 13, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  13   7
# Current state:  487
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  123669.32000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.18, 'scoreIncrement': 0.01, 'newState': {'x': '13', 'y': 8}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  13   8
# Current state:  527
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.18
# cumulative reward from the world so far:  123669.50000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': 14, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  14   8
# Current state:  528
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  123669.69000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': 15, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  15   8
# Current state:  568
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  123669.88000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.2, 'scoreIncrement': 0.01, 'newState': {'x': 16, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  16   8
# Current state:  608
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.2
# cumulative reward from the world so far:  123670.08000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.19, 'scoreIncrement': 0.01, 'newState': {'x': '16', 'y': 7}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  16   7
# Current state:  648
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  123670.27000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.2, 'scoreIncrement': 0.01, 'newState': {'x': 17, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   7
# Current state:  647
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.2
# cumulative reward from the world so far:  123670.47000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.21, 'scoreIncrement': 0.01, 'newState': {'x': '17', 'y': 8}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   8
# Current state:  687
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.21
# cumulative reward from the world so far:  123670.68000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.22, 'scoreIncrement': 0.01, 'newState': {'x': '17', 'y': 9}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   9
# Current state:  688
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  123670.90000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.23, 'scoreIncrement': 0.01, 'newState': {'x': 18, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  18   9
# Current state:  689
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.23
# cumulative reward from the world so far:  123671.13000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.24, 'scoreIncrement': 0.01, 'newState': {'x': '18', 'y': 10}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  18   10
# Current state:  729
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.24
# cumulative reward from the world so far:  123671.37000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.25, 'scoreIncrement': 0.01, 'newState': {'x': '18', 'y': 11}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  18   11
# Current state:  730
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.25
# cumulative reward from the world so far:  123671.62000000023
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.26, 'scoreIncrement': 0.01, 'newState': {'x': 19, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  19   11
# Current state:  731
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.26
# cumulative reward from the world so far:  123671.88000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.25, 'scoreIncrement': 0.01, 'newState': {'x': 18, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  18   11
# Current state:  771
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.25
# cumulative reward from the world so far:  123672.13000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.26, 'scoreIncrement': 0.01, 'newState': {'x': '18', 'y': 12}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  18   12
# Current state:  731
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.26
# cumulative reward from the world so far:  123672.39000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.28, 'scoreIncrement': 0.01, 'newState': {'x': '18', 'y': 13}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  18   13
# Current state:  732
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.28
# cumulative reward from the world so far:  123672.67000000022
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': 17, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   13
# Current state:  733
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.26
# cumulative reward from the world so far:  123672.93000000021
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.28, 'scoreIncrement': 0, 'newState': {'x': '17', 'y': 14}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   14
# Current state:  693
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.28
# cumulative reward from the world so far:  123673.21000000021
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.29, 'scoreIncrement': 0, 'newState': {'x': '17', 'y': 15}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   15
# Current state:  694
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.29
# cumulative reward from the world so far:  123673.5000000002
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.31, 'scoreIncrement': 0, 'newState': {'x': '17', 'y': 16}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   16
# Current state:  695
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.31
# cumulative reward from the world so far:  123673.8100000002
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '51289', 'reward': 0.33, 'scoreIncrement': 0, 'newState': {'x': '17', 'y': 17}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  17   17
# Current state:  696
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.33
# cumulative reward from the world so far:  123674.1400000002

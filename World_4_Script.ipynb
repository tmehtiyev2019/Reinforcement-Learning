# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=4
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1

        while True:
            action = np.argmax(Q[world_id, state])
            
            # Choose action using epsilon-greedy strategy
            
#             action = np.argmax(Q[world_id, state])
            if random.uniform(0, 1) <= adjusted_epsilon:
                action=0 #east
#                 action=2 #south
            
#                 for a in range(n_actions):
#                     if Q[world_id, state, a]==0:
#                         action=0
#                         break
#                     else:
#                         action = np.argmax(Q[world_id, state])
#                         break
                        
#                 while True:
#                     a = random.randint(0, n_actions - 1)
#                     if Q[world_id, state, a]>=np.mean(Q[world_id, state]) or Q[world_id, state, a]==0:
#                         action=a
#                         break

            else:
                action=2 #south
#                 action = np.argmax(Q[world_id, state])
#             action = np.argmax(Q[world_id, state])
            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.   3.   2.   2. 118.   2.   2.   2.   2.   2.   2.]
# 4  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.06, 'scoreIncrement': 0.06, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.06
# cumulative reward from the world so far:  10910130.460000196
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.06, 'scoreIncrement': 0.05, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.06
# cumulative reward from the world so far:  10910130.520000197
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.06, 'scoreIncrement': 0.05, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.06
# cumulative reward from the world so far:  10910130.580000198
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.06, 'scoreIncrement': 0.04, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.06
# cumulative reward from the world so far:  10910130.640000198
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.05, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910130.710000198
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.04, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910130.780000199
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.04, 'newState': {'x': '3', 'y': 2}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  3   2
# Current state:  121
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910130.850000199
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.03, 'newState': {'x': 4, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  4   2
# Current state:  122
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910130.9200002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.03, 'newState': {'x': 5, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  5   2
# Current state:  162
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910130.9900002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.03, 'newState': {'x': '5', 'y': 3}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  5   3
# Current state:  202
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910131.0600002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.02, 'newState': {'x': '5', 'y': 4}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  5   4
# Current state:  203
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910131.1300002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.02, 'newState': {'x': 6, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  6   4
# Current state:  204
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910131.2000002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.02, 'newState': {'x': 5, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  5   4
# Current state:  244
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910131.2700002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.02, 'newState': {'x': '5', 'y': 5}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  5   5
# Current state:  204
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910131.340000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.02, 'newState': {'x': '5', 'y': 6}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  5   6
# Current state:  205
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910131.410000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.01, 'newState': {'x': 6, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  6   6
# Current state:  206
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910131.480000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.08, 'scoreIncrement': 0.01, 'newState': {'x': '6', 'y': 7}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  6   7
# Current state:  246
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.08
# cumulative reward from the world so far:  10910131.560000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.07, 'scoreIncrement': 0.01, 'newState': {'x': '6', 'y': 6}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  6   6
# Current state:  247
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  10910131.630000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.08, 'scoreIncrement': 0.01, 'newState': {'x': 7, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  7   6
# Current state:  246
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.08
# cumulative reward from the world so far:  10910131.710000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.08, 'scoreIncrement': 0.01, 'newState': {'x': '7', 'y': 7}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  7   7
# Current state:  286
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.08
# cumulative reward from the world so far:  10910131.790000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.08, 'scoreIncrement': 0.01, 'newState': {'x': '7', 'y': 8}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  7   8
# Current state:  287
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.08
# cumulative reward from the world so far:  10910131.870000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.08, 'scoreIncrement': 0.01, 'newState': {'x': 8, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  8   8
# Current state:  288
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.08
# cumulative reward from the world so far:  10910131.950000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.08, 'scoreIncrement': 0.01, 'newState': {'x': 9, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  9   8
# Current state:  328
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.08
# cumulative reward from the world so far:  10910132.030000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.08, 'scoreIncrement': 0.01, 'newState': {'x': 10, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  10   8
# Current state:  368
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.08
# cumulative reward from the world so far:  10910132.110000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.08, 'scoreIncrement': 0.01, 'newState': {'x': 11, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  11   8
# Current state:  408
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.08
# cumulative reward from the world so far:  10910132.190000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.08, 'scoreIncrement': 0.01, 'newState': {'x': 12, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  12   8
# Current state:  448
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.08
# cumulative reward from the world so far:  10910132.270000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.09, 'scoreIncrement': 0.01, 'newState': {'x': 13, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  13   8
# Current state:  488
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.09
# cumulative reward from the world so far:  10910132.360000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.09, 'scoreIncrement': 0.01, 'newState': {'x': '13', 'y': 9}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  13   9
# Current state:  528
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.09
# cumulative reward from the world so far:  10910132.450000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.09, 'scoreIncrement': 0, 'newState': {'x': '13', 'y': 10}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  13   10
# Current state:  529
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.09
# cumulative reward from the world so far:  10910132.540000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.09, 'scoreIncrement': 0, 'newState': {'x': 14, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  14   10
# Current state:  530
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.09
# cumulative reward from the world so far:  10910132.630000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.09, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 9}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  14   9
# Current state:  570
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.09
# cumulative reward from the world so far:  10910132.720000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.09, 'scoreIncrement': 0, 'newState': {'x': '14', 'y': 10}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  14   10
# Current state:  569
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.09
# cumulative reward from the world so far:  10910132.810000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.09, 'scoreIncrement': 0, 'newState': {'x': 15, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  15   10
# Current state:  570
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.09
# cumulative reward from the world so far:  10910132.900000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.09, 'scoreIncrement': 0, 'newState': {'x': '15', 'y': 11}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  15   11
# Current state:  610
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.09
# cumulative reward from the world so far:  10910132.990000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.1, 'scoreIncrement': 0, 'newState': {'x': 16, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  16   11
# Current state:  611
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.1
# cumulative reward from the world so far:  10910133.090000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.1, 'scoreIncrement': 0, 'newState': {'x': 17, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  17   11
# Current state:  651
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  10910133.1900002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.1, 'scoreIncrement': 0, 'newState': {'x': 18, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  18   11
# Current state:  691
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  10910133.2900002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.1, 'scoreIncrement': 0, 'newState': {'x': 19, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  19   11
# Current state:  731
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.1
# cumulative reward from the world so far:  10910133.3900002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.1, 'scoreIncrement': 0, 'newState': {'x': 20, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  20   11
# Current state:  771
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  10910133.4900002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 21, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  21   11
# Current state:  811
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  10910133.600000199
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '21', 'y': 12}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  21   12
# Current state:  851
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  10910133.710000198
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 22, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  22   12
# Current state:  852
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  10910133.820000198
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 13}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  22   13
# Current state:  892
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  10910133.930000197
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 14}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  22   14
# Current state:  893
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  10910134.050000196
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 15}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  22   15
# Current state:  894
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  10910134.170000196
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': 23, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  23   15
# Current state:  895
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  10910134.290000195
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.13, 'scoreIncrement': 0, 'newState': {'x': '23', 'y': 16}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  23   16
# Current state:  935
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  10910134.420000196
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.13, 'scoreIncrement': 0, 'newState': {'x': '23', 'y': 17}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  23   17
# Current state:  936
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  10910134.550000196
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.13, 'scoreIncrement': 0, 'newState': {'x': '23', 'y': 18}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  23   18
# Current state:  937
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  10910134.680000197
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.14, 'scoreIncrement': 0, 'newState': {'x': 24, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  24   18
# Current state:  938
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  10910134.820000198
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.13, 'scoreIncrement': 0, 'newState': {'x': 23, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  23   18
# Current state:  978
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  10910134.950000199
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.14, 'scoreIncrement': 0, 'newState': {'x': '23', 'y': 19}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  23   19
# Current state:  938
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  10910135.0900002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.14, 'scoreIncrement': 0, 'newState': {'x': '23', 'y': 20}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  23   20
# Current state:  939
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  10910135.2300002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.14, 'scoreIncrement': 0, 'newState': {'x': '23', 'y': 21}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  23   21
# Current state:  940
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  10910135.3700002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.15, 'scoreIncrement': 0, 'newState': {'x': 24, 'y': '21'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  24   21
# Current state:  941
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  10910135.5200002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.15, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 22}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  24   22
# Current state:  981
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  10910135.670000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 23}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  24   23
# Current state:  982
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  10910135.830000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 24}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  24   24
# Current state:  983
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  10910135.990000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 25}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  24   25
# Current state:  984
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  10910136.160000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 26}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  24   26
# Current state:  985
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  10910136.330000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.18, 'scoreIncrement': 0, 'newState': {'x': 25, 'y': '26'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  25   26
# Current state:  986
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.18
# cumulative reward from the world so far:  10910136.510000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': 24, 'y': '26'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  24   26
# Current state:  1026
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.17
# cumulative reward from the world so far:  10910136.6800002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.18, 'scoreIncrement': 0, 'newState': {'x': 25, 'y': '26'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  25   26
# Current state:  986
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.18
# cumulative reward from the world so far:  10910136.8600002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': 26, 'y': '26'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  26   26
# Current state:  1026
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  10910137.0500002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '26', 'y': 27}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  26   27
# Current state:  1066
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  10910137.2400002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.2, 'scoreIncrement': 0, 'newState': {'x': 27, 'y': '27'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  27   27
# Current state:  1067
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.2
# cumulative reward from the world so far:  10910137.440000199
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.21, 'scoreIncrement': 0, 'newState': {'x': 28, 'y': '27'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  28   27
# Current state:  1107
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.21
# cumulative reward from the world so far:  10910137.6500002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': 29, 'y': '27'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  29   27
# Current state:  1147
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  10910137.8700002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': '29', 'y': 28}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  29   28
# Current state:  1187
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.23
# cumulative reward from the world so far:  10910138.1000002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': '29', 'y': 29}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  29   29
# Current state:  1188
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.24
# cumulative reward from the world so far:  10910138.340000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': 30, 'y': '29'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  30   29
# Current state:  1189
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.25
# cumulative reward from the world so far:  10910138.590000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': '30', 'y': 30}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  30   30
# Current state:  1229
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.26
# cumulative reward from the world so far:  10910138.8500002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.28, 'scoreIncrement': 0, 'newState': {'x': '30', 'y': 31}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  30   31
# Current state:  1230
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.28
# cumulative reward from the world so far:  10910139.1300002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.29, 'scoreIncrement': 0, 'newState': {'x': 31, 'y': '31'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  31   31
# Current state:  1231
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.29
# cumulative reward from the world so far:  10910139.4200002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.31, 'scoreIncrement': 0, 'newState': {'x': 32, 'y': '31'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  32   31
# Current state:  1271
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.31
# cumulative reward from the world so far:  10910139.7300002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.33, 'scoreIncrement': 0, 'newState': {'x': 33, 'y': '31'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  33   31
# Current state:  1311
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.33
# cumulative reward from the world so far:  10910140.0600002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.31, 'scoreIncrement': 0, 'newState': {'x': '33', 'y': 30}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  33   30
# Current state:  1351
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.31
# cumulative reward from the world so far:  10910140.3700002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.33, 'scoreIncrement': 0, 'newState': {'x': 34, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  34   30
# Current state:  1350
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.33
# cumulative reward from the world so far:  10910140.7000002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.36, 'scoreIncrement': 0, 'newState': {'x': 35, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  35   30
# Current state:  1390
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.36
# cumulative reward from the world so far:  10910141.0600002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.38, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 31}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  35   31
# Current state:  1430
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.38
# cumulative reward from the world so far:  10910141.4400002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.42, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 32}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  35   32
# Current state:  1431
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.42
# cumulative reward from the world so far:  10910141.8600002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': 36, 'y': '32'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  36   32
# Current state:  1432
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.45
# cumulative reward from the world so far:  10910142.3100002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 33}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  36   33
# Current state:  1472
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.5
# cumulative reward from the world so far:  10910142.8100002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 34}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  36   34
# Current state:  1473
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.56
# cumulative reward from the world so far:  10910143.3700002
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 35}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  36   35
# Current state:  1474
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.63
# cumulative reward from the world so far:  10910144.000000201
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.71, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 36}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  36   36
# Current state:  1475
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.71
# cumulative reward from the world so far:  10910144.710000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 37}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  36   37
# Current state:  1476
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  10910145.540000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 37, 'y': '37'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  37   37
# Current state:  1477
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  10910146.540000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': '37', 'y': 38}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  37   38
# Current state:  1517
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.25
# cumulative reward from the world so far:  10910147.790000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 1.67, 'scoreIncrement': 0, 'newState': {'x': 38, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  38   38
# Current state:  1518
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.67
# cumulative reward from the world so far:  10910149.460000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': 37, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  37   38
# Current state:  1558
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.25
# cumulative reward from the world so far:  10910150.710000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 1.67, 'scoreIncrement': 0, 'newState': {'x': 38, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  38   38
# Current state:  1518
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.67
# cumulative reward from the world so far:  10910152.380000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 2.5, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  39   38
# Current state:  1558
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  2.5
# cumulative reward from the world so far:  10910154.880000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 5, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  39   39
# Current state:  1598
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  5.0
# cumulative reward from the world so far:  10910159.880000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 100000, 'scoreIncrement': 5, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 4, 'runId': '50173', 'reward': 100000, 'scoreIncrement': 5, 'newState': None}
# 4  ended
# [  0.   3.   2.   2. 119.   2.   2.   2.   2.   2.   2.]
# 4  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.06, 'scoreIncrement': 0.06, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.06
# cumulative reward from the world so far:  11010159.940000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.06, 'scoreIncrement': 0.05, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.06
# cumulative reward from the world so far:  11010160.000000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.06, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.070000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.05, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.140000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.05, 'newState': {'x': '3', 'y': 2}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  3   2
# Current state:  121
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.210000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.04, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   2
# Current state:  122
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.280000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.04, 'newState': {'x': '2', 'y': 3}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   3
# Current state:  82
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.350000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.03, 'newState': {'x': '2', 'y': 4}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   4
# Current state:  83
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.420000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.03, 'newState': {'x': '2', 'y': 5}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   5
# Current state:  84
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.490000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.03, 'newState': {'x': '2', 'y': 6}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   6
# Current state:  85
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.560000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.02, 'newState': {'x': '2', 'y': 5}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   5
# Current state:  86
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.630000206
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.02, 'newState': {'x': 3, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  3   5
# Current state:  85
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.700000206
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.02, 'newState': {'x': 4, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  4   5
# Current state:  125
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.770000206
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.02, 'newState': {'x': '4', 'y': 6}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  4   6
# Current state:  165
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.840000207
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.02, 'newState': {'x': '4', 'y': 7}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  4   7
# Current state:  166
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.910000207
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.07, 'scoreIncrement': 0.01, 'newState': {'x': 5, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  5   7
# Current state:  167
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11010160.980000207
# printing the response:
# ...
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '28', 'y': 25}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  28   25
# Current state:  1144
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  11010166.500000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': 27, 'y': '25'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  27   25
# Current state:  1145
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  11010166.690000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '27', 'y': 26}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  27   26
# Current state:  1105
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  11010166.880000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '27', 'y': 25}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  27   25
# Current state:  1106
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  11010167.070000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': 28, 'y': '25'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  28   25
# Current state:  1105
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  11010167.260000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.2, 'scoreIncrement': 0, 'newState': {'x': '28', 'y': 26}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  28   26
# Current state:  1145
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.2
# cumulative reward from the world so far:  11010167.460000202
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.21, 'scoreIncrement': 0, 'newState': {'x': '28', 'y': 27}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  28   27
# Current state:  1146
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.21
# cumulative reward from the world so far:  11010167.670000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': '28', 'y': 28}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  28   28
# Current state:  1147
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  11010167.890000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': '28', 'y': 29}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  28   29
# Current state:  1148
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.23
# cumulative reward from the world so far:  11010168.120000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': 29, 'y': '29'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  29   29
# Current state:  1149
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.24
# cumulative reward from the world so far:  11010168.360000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': 30, 'y': '29'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  30   29
# Current state:  1189
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.25
# cumulative reward from the world so far:  11010168.610000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': 31, 'y': '29'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  31   29
# Current state:  1229
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.26
# cumulative reward from the world so far:  11010168.870000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.28, 'scoreIncrement': 0, 'newState': {'x': '31', 'y': 30}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  31   30
# Current state:  1269
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.28
# cumulative reward from the world so far:  11010169.150000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.29, 'scoreIncrement': 0, 'newState': {'x': 32, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  32   30
# Current state:  1270
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.29
# cumulative reward from the world so far:  11010169.440000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.31, 'scoreIncrement': 0, 'newState': {'x': 33, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  33   30
# Current state:  1310
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.31
# cumulative reward from the world so far:  11010169.750000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.33, 'scoreIncrement': 0, 'newState': {'x': 34, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  34   30
# Current state:  1350
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.33
# cumulative reward from the world so far:  11010170.080000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.36, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 31}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  34   31
# Current state:  1390
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.36
# cumulative reward from the world so far:  11010170.440000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.38, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 32}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  34   32
# Current state:  1391
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.38
# cumulative reward from the world so far:  11010170.820000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.42, 'scoreIncrement': 0, 'newState': {'x': 35, 'y': '32'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  35   32
# Current state:  1392
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.42
# cumulative reward from the world so far:  11010171.240000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 33}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  35   33
# Current state:  1432
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.45
# cumulative reward from the world so far:  11010171.690000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 34}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  35   34
# Current state:  1433
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.5
# cumulative reward from the world so far:  11010172.190000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': 36, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  36   34
# Current state:  1434
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.56
# cumulative reward from the world so far:  11010172.750000203
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 35}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  36   35
# Current state:  1474
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.63
# cumulative reward from the world so far:  11010173.380000204
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.71, 'scoreIncrement': 0, 'newState': {'x': 37, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  37   35
# Current state:  1475
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.71
# cumulative reward from the world so far:  11010174.090000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': 38, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  38   35
# Current state:  1515
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  11010174.920000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '38', 'y': 36}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  38   36
# Current state:  1555
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  11010175.920000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '36'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  39   36
# Current state:  1556
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.25
# cumulative reward from the world so far:  11010177.170000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': 39, 'y': '36'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  39   36
# Current state:  1596
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.25
# cumulative reward from the world so far:  11010178.420000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 1.67, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 37}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  39   37
# Current state:  1596
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.67
# cumulative reward from the world so far:  11010180.090000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 2.5, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 38}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  39   38
# Current state:  1597
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  2.5
# cumulative reward from the world so far:  11010182.590000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 5, 'scoreIncrement': 0, 'newState': {'x': '39', 'y': 39}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  39   39
# Current state:  1598
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  5.0
# cumulative reward from the world so far:  11010187.590000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 100000, 'scoreIncrement': 5.55, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 4, 'runId': '50176', 'reward': 100000, 'scoreIncrement': 5.55, 'newState': None}
# 4  ended
# [  0.   3.   2.   2. 120.   2.   2.   2.   2.   2.   2.]
# 4  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50178', 'reward': 0.06, 'scoreIncrement': 0.06, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.06
# cumulative reward from the world so far:  11110187.650000205
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50178', 'reward': 0.06, 'scoreIncrement': 0.05, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.06
# cumulative reward from the world so far:  11110187.710000206
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50178', 'reward': 0.07, 'scoreIncrement': 0.06, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11110187.780000206
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50178', 'reward': 0.07, 'scoreIncrement': 0.05, 'newState': {'x': '3', 'y': 1}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  3   1
# Current state:  120
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11110187.850000206
# printing the response:
#  {'code': 'OK', 'worldId': 4, 'runId': '50178', 'reward': 0.07, 'scoreIncrement': 0.05, 'newState': {'x': '3', 'y': 2}}
# Visual of the given details is printed above
# World Number:  4
# Current state row and column:  3   2
# Current state:  121
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.07
# cumulative reward from the world so far:  11110187.920000207

# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = 1
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=1
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1

        while True:
            
            
            
            
            # Choose action using epsilon-greedy strategy
            
#             action = np.argmax(Q[world_id, state])
            if random.uniform(0, 1) <= adjusted_epsilon:
#                 while True:
#                     a = random.randint(0, 3)
#                     if Q[world_id, state, a]!= np.argmin(Q[world_id, state]) or Q[world_id, state, a]==0:
#                         action=a
#                         break

        
                for a in range(n_actions):
                    if Q[world_id, state, a]==0:
                        action=a
                        break
                    else:
                        action = random.randint(0, 3)
#                         if Q[world_id, state, a]!= np.argmin(Q[world_id, state]):
#                             action=a
                        
#             else :
#                 action=np.argmax(Q[world_id, state])
                        
#                         while True:
#                             a = random.randint(0, 3)
#                             if Q[world_id, state, a]!= np.argmin(Q[world_id, state]):
#                                 action=a
#                                 break
                        

#             else:

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                print("Last action to terminal: ", action )
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        
        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        if reward>0:
            break
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# # Print the learned policy
# for world_id in range(n_worlds):
#     print(f"World {world_id}:")
#     for state in range(n_states):
#         print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.   3.   2.   2. 186.  34. 147.  37.   9.   2.   2.]
# 1  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 1.0
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.1, 'scoreIncrement': 0.1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  -8145.359999999701
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.1, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8145.249999999702
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.1, 'scoreIncrement': 0.08, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.1
# cumulative reward from the world so far:  -8145.149999999701
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.08, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8145.039999999702
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.07, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8144.929999999702
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.06, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  3
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8144.819999999702
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.1, 'scoreIncrement': 0.05, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   1
# Current state:  2
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.1
# cumulative reward from the world so far:  -8144.719999999702
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.1, 'scoreIncrement': 0.05, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   1
# Current state:  1
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.1
# cumulative reward from the world so far:  -8144.619999999702
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.05, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8144.509999999702
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.04, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8144.399999999702
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.04, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   0
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8144.289999999703
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.03, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8144.179999999703
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.1, 'scoreIncrement': 0.03, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   0
# Current state:  80
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.1
# cumulative reward from the world so far:  -8144.0799999997025
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.03, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8143.969999999703
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.03, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8143.859999999703
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.02, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8143.7499999997035
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.02, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  2
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8143.639999999704
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.02, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8143.529999999704
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.02, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8143.4199999997045
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': '0', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  3
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8143.309999999705
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  4
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8143.199999999705
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   3
# Current state:  44
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8143.0899999997055
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  43
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8142.979999999706
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  3
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8142.869999999706
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  2
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8142.759999999706
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  2
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8142.649999999707
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.1, 'scoreIncrement': 0.01, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   1
# Current state:  2
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.1
# cumulative reward from the world so far:  -8142.549999999706
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8142.439999999707
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   2
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8142.329999999707
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8142.219999999707
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8142.109999999708
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   3
# Current state:  3
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8141.999999999708
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  43
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8141.889999999708
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  3
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8141.779999999709
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8141.669999999709
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8141.559999999709
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8141.44999999971
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  3
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8141.33999999971
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  2
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8141.22999999971
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8141.119999999711
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8141.009999999711
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  3
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8140.899999999711
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  4
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8140.789999999712
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  4
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8140.679999999712
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  4
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8140.569999999712
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8140.459999999713
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   5
# Current state:  4
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8140.349999999713
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   5
# Current state:  5
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8140.229999999713
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  45
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8140.119999999713
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8140.009999999714
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  4
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8139.899999999714
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   5
# Current state:  44
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8139.779999999714
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  45
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8139.6699999997145
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8139.559999999715
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   5
# Current state:  4
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8139.449999999715
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  5
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8139.3399999997155
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   5
# Current state:  4
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8139.229999999716
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   5
# Current state:  5
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8139.119999999716
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   5
# Current state:  5
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8138.999999999716
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   5
# Current state:  45
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8138.889999999717
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   5
# Current state:  5
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8138.769999999717
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  45
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8138.659999999717
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8138.549999999717
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  4
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8138.439999999718
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8138.329999999718
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  4
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8138.219999999718
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   3
# Current state:  44
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8138.109999999719
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8137.999999999719
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8137.889999999719
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   5
# Current state:  4
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8137.77999999972
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  5
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8137.66999999972
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   5
# Current state:  4
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8137.55999999972
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  5
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8137.449999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   5
# Current state:  4
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8137.339999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 6}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   6
# Current state:  5
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8137.219999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 7}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   7
# Current state:  6
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8137.099999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 6}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   6
# Current state:  7
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8136.979999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   5
# Current state:  6
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8136.869999999722
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   5
# Current state:  5
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8136.749999999722
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 6}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   6
# Current state:  45
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8136.629999999722
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   6
# Current state:  46
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8136.509999999722
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   6
# Current state:  86
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8136.389999999722
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 5}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   5
# Current state:  46
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8136.269999999722
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  45
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8136.1599999997225
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8136.049999999723
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  4
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8135.939999999723
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8135.829999999723
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  4
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8135.719999999724
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   2
# Current state:  3
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8135.609999999724
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   2
# Current state:  2
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8135.499999999724
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   3
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8135.389999999725
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  43
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8135.279999999725
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8135.169999999725
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8135.059999999726
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8134.949999999726
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8134.839999999726
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  3
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8134.729999999727
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  4
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8134.619999999727
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  4
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8134.509999999727
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8134.399999999728
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8134.289999999728
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8134.179999999728
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '0', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  3
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8134.069999999729
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  4
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8133.959999999729
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  4
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8133.849999999729
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  44
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8133.73999999973
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 0, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  0   4
# Current state:  4
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8133.62999999973
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  4
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8133.51999999973
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.12, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  2   4
# Current state:  44
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  -8133.39999999973
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  84
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8133.289999999731
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   3
# Current state:  44
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8133.179999999731
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.11, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  -8133.069999999731
# printing the response:
# ...
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.29, 'scoreIncrement': 0, 'newState': {'x': 30, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  30   34
# Current state:  1274
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.29
# cumulative reward from the world so far:  -8013.219999999718
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.28, 'scoreIncrement': 0, 'newState': {'x': 31, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  31   34
# Current state:  1234
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.28
# cumulative reward from the world so far:  -8012.939999999719
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': 32, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  32   34
# Current state:  1274
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.26
# cumulative reward from the world so far:  -8012.679999999718
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': '32', 'y': 35}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  32   35
# Current state:  1314
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.25
# cumulative reward from the world so far:  -8012.429999999718
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': 31, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  31   35
# Current state:  1315
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.26
# cumulative reward from the world so far:  -8012.169999999718
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': 32, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  32   35
# Current state:  1275
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.25
# cumulative reward from the world so far:  -8011.919999999718
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': 33, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  33   35
# Current state:  1315
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.24
# cumulative reward from the world so far:  -8011.679999999718
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': '33', 'y': 36}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  33   36
# Current state:  1355
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.23
# cumulative reward from the world so far:  -8011.449999999719
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': 32, 'y': '36'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  32   36
# Current state:  1356
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.24
# cumulative reward from the world so far:  -8011.209999999719
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': '32', 'y': 37}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  32   37
# Current state:  1316
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.23
# cumulative reward from the world so far:  -8010.979999999719
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': '32', 'y': 36}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  32   36
# Current state:  1317
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.24
# cumulative reward from the world so far:  -8010.73999999972
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': '32', 'y': 35}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  32   35
# Current state:  1316
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.25
# cumulative reward from the world so far:  -8010.48999999972
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': 33, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  33   35
# Current state:  1315
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.24
# cumulative reward from the world so far:  -8010.24999999972
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': '33', 'y': 34}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  33   34
# Current state:  1355
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.25
# cumulative reward from the world so far:  -8009.99999999972
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': '33', 'y': 35}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  33   35
# Current state:  1354
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.24
# cumulative reward from the world so far:  -8009.75999999972
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': 34, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  34   35
# Current state:  1355
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.23
# cumulative reward from the world so far:  -8009.5299999997205
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 36}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  34   36
# Current state:  1395
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  -8009.30999999972
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 35}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  34   35
# Current state:  1396
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.23
# cumulative reward from the world so far:  -8009.079999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 34}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  34   34
# Current state:  1395
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.24
# cumulative reward from the world so far:  -8008.839999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 35}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  34   35
# Current state:  1394
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.23
# cumulative reward from the world so far:  -8008.609999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': 35, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  35   35
# Current state:  1395
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.22
# cumulative reward from the world so far:  -8008.389999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.21, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 36}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  35   36
# Current state:  1435
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.21
# cumulative reward from the world so far:  -8008.179999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.2, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 37}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  35   37
# Current state:  1436
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.2
# cumulative reward from the world so far:  -8007.979999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.21, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 36}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  35   36
# Current state:  1437
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.21
# cumulative reward from the world so far:  -8007.769999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 35}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  35   35
# Current state:  1436
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.22
# cumulative reward from the world so far:  -8007.549999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 34}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  35   34
# Current state:  1435
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.23
# cumulative reward from the world so far:  -8007.319999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': '35', 'y': 35}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  35   35
# Current state:  1434
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  -8007.099999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.21, 'scoreIncrement': 0, 'newState': {'x': 36, 'y': '35'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  36   35
# Current state:  1435
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.21
# cumulative reward from the world so far:  -8006.889999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.2, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 36}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  36   36
# Current state:  1475
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.2
# cumulative reward from the world so far:  -8006.689999999721
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 37}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  36   37
# Current state:  1476
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  -8006.499999999722
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 38}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  36   38
# Current state:  1477
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  -8006.309999999722
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '36', 'y': 37}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  36   37
# Current state:  1478
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.19
# cumulative reward from the world so far:  -8006.1199999997225
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': 37, 'y': '37'}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  37   37
# Current state:  1477
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.19
# cumulative reward from the world so far:  -8005.929999999723
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.18, 'scoreIncrement': 0, 'newState': {'x': '37', 'y': 38}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  37   38
# Current state:  1517
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.18
# cumulative reward from the world so far:  -8005.749999999723
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '37', 'y': 37}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  37   37
# Current state:  1518
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.19
# cumulative reward from the world so far:  -8005.559999999723
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '37', 'y': 36}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  37   36
# Current state:  1517
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  0.19
# cumulative reward from the world so far:  -8005.369999999723
# printing the response:
#  {'code': 'OK', 'worldId': 1, 'runId': '50898', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '37', 'y': 37}}
# Visual of the given details is printed above
# World Number:  1
# Current state row and column:  37   37
# Current state:  1516
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  -8005.179999999724

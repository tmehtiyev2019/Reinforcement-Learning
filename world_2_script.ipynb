# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 1000
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
#         if min(world_traversal_count[1:])<minimum_traversal_requirement:
#             world_id=np.argmin(world_traversal_count[1:])+1
#             print(world_traversal_count)
#         else:
#             world_id=np.argmax(score_map[1:])+1
#             print(score_map)

        world_id=2
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1
        next_state_row, next_state_col=0,0

        while True:
            while True:


                if next_state_row==17 and next_state_col==11:
                    action=1
                    action = np.argmax(Q[world_id, state])


                # Choose action using epsilon-greedy strategy

    #             action = np.argmax(Q[world_id, state])
                elif random.uniform(0, 1) <= adjusted_epsilon:
                    if next_state_row != 17:
                        if next_state_row<17:
                            action=2
                        elif next_state_row>17:
                            action=3


                elif next_state_col!=11:
                    if next_state_col<11:
                        action=0
                    elif next_state_col>11:
                        action=1     
    #             elif:
    #                 state_row==20 and state_col==30:
    #                 action=1
    #                 action = np.argmax(Q[world_id, state])

                if Q[world_id, state, action]!= np.argmin(Q[world_id, state]) or Q[world_id, state, action]==0:
                    break

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# 2  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53073.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53074.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53075.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '3', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   1
# Current state:  120
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53076.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   1
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53077.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 5, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   1
# Current state:  161
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53078.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '5', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   2
# Current state:  201
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53079.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 6, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   2
# Current state:  202
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53080.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '6', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   3
# Current state:  242
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53081.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': '6', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   4
# Current state:  243
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53082.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': 7, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   4
# Current state:  244
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53083.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '7', 'y': 5}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   5
# Current state:  284
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53084.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': 8, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   5
# Current state:  285
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53085.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '8', 'y': 6}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   6
# Current state:  325
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53086.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': '8', 'y': 7}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   7
# Current state:  326
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53087.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': '8', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   8
# Current state:  327
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53088.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': '8', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   9
# Current state:  328
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53089.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': '8', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   10
# Current state:  329
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53090.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': 9, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   10
# Current state:  330
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53091.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': '9', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   11
# Current state:  370
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53092.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': '9', 'y': 12}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   12
# Current state:  371
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53093.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': '9', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   11
# Current state:  372
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53094.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': 10, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   11
# Current state:  371
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53095.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': 11, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   11
# Current state:  411
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53096.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': 12, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   11
# Current state:  451
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53097.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': 13, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   11
# Current state:  491
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53098.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 14, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   11
# Current state:  531
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53099.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 15, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   11
# Current state:  571
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53100.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 16, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   11
# Current state:  611
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53101.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': '16', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   10
# Current state:  651
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53102.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': '16', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   11
# Current state:  650
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53103.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 17, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  17   11
# Current state:  651
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53104.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1000, 'scoreIncrement': 34.34, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 2, 'runId': '52360', 'reward': 1000, 'scoreIncrement': 34.34, 'newState': None}
# 2  ended
# 2  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54105.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54106.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54107.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 0, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   3
# Current state:  3
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54108.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   3
# Current state:  3
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54109.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54110.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '1', 'y': 5}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   5
# Current state:  44
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54111.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '1', 'y': 6}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   6
# Current state:  45
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54112.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '1', 'y': 7}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   7
# Current state:  46
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54113.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 2, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   7
# Current state:  47
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54114.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': 3, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   7
# Current state:  87
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54115.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '3', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   8
# Current state:  127
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54116.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': '3', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   9
# Current state:  128
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54117.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '3', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   8
# Current state:  129
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54118.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': '3', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   9
# Current state:  128
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54119.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': '3', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   10
# Current state:  129
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54120.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 4, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   10
# Current state:  130
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54121.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': 5, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   10
# Current state:  170
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54122.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': 6, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   10
# Current state:  210
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54123.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': '6', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   11
# Current state:  250
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54124.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': '6', 'y': 12}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   12
# Current state:  251
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54125.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': 7, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   12
# Current state:  252
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54126.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': '7', 'y': 13}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   13
# Current state:  292
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54127.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': '7', 'y': 14}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   14
# Current state:  293
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54128.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': 8, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   14
# Current state:  294
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54129.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': 9, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   14
# Current state:  334
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54130.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 10, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   14
# Current state:  374
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54131.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 11, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   14
# Current state:  414
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54132.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 12, 'y': '14'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   14
# Current state:  454
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54133.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': '12', 'y': 13}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   13
# Current state:  494
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54134.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 13, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   13
# Current state:  493
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54135.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 14, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   13
# Current state:  533
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54136.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '14', 'y': 12}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   12
# Current state:  573
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54137.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '14', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   11
# Current state:  572
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54138.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 15, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   11
# Current state:  571
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54139.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 16, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   11
# Current state:  611
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54140.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': 17, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  17   11
# Current state:  651
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  54141.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1000, 'scoreIncrement': 20.28, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 2, 'runId': '52361', 'reward': 1000, 'scoreIncrement': 20.28, 'newState': None}
# 2  ended
# 2  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55142.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55143.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   2
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55144.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55145.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '2', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   3
# Current state:  82
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55146.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   2
# Current state:  83
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55147.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55148.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 4, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   2
# Current state:  122
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55149.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '4', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   3
# Current state:  162
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55150.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': '4', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   4
# Current state:  163
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55151.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '4', 'y': 5}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   5
# Current state:  164
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55152.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': 5, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   5
# Current state:  165
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55153.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': '5', 'y': 6}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   6
# Current state:  205
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55154.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': 6, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   6
# Current state:  206
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55155.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': '6', 'y': 7}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   7
# Current state:  246
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55156.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': 7, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   7
# Current state:  247
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55157.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 8, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   7
# Current state:  287
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55158.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': 9, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   7
# Current state:  327
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55159.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': '9', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   8
# Current state:  367
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55160.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': '9', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   9
# Current state:  368
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55161.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': 10, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   9
# Current state:  369
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55162.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': '10', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   10
# Current state:  409
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55163.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': '10', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   11
# Current state:  410
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55164.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': 11, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   11
# Current state:  411
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55165.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': 12, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   11
# Current state:  451
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55166.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': 13, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   11
# Current state:  491
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55167.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': '13', 'y': 12}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   12
# Current state:  531
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55168.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 12, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   12
# Current state:  532
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55169.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 13, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   12
# Current state:  492
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55170.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 14, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   12
# Current state:  532
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55171.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': '14', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   11
# Current state:  572
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55172.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': '14', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   10
# Current state:  571
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55173.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '14', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   11
# Current state:  570
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55174.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '14', 'y': 12}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   12
# Current state:  571
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55175.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '14', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   11
# Current state:  572
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55176.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '14', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   10
# Current state:  571
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55177.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': 15, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   10
# Current state:  570
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55178.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': '15', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   9
# Current state:  610
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55179.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': '15', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   10
# Current state:  609
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55180.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': 16, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   10
# Current state:  610
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55181.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 17, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  17   10
# Current state:  650
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55182.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '17', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  17   11
# Current state:  690
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  55183.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1000, 'scoreIncrement': 11.97, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 2, 'runId': '52362', 'reward': 1000, 'scoreIncrement': 11.97, 'newState': None}
# 2  ended
# 2  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52364', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  56184.0
# ...
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65530.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65531.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65532.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': '2', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   3
# Current state:  82
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65533.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': '2', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   4
# Current state:  83
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65534.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '2', 'y': 5}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   5
# Current state:  84
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65535.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '2', 'y': 6}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   6
# Current state:  85
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65536.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '2', 'y': 7}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   7
# Current state:  86
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65537.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 3, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   7
# Current state:  87
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65538.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '3', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   8
# Current state:  127
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65539.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '3', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   9
# Current state:  128
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65540.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': 4, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   9
# Current state:  129
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65541.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '4', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   8
# Current state:  169
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65542.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': 3, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   8
# Current state:  168
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65543.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': 4, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   8
# Current state:  128
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65544.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 5, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   8
# Current state:  168
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65545.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': 4, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   8
# Current state:  208
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65546.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': 5, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   8
# Current state:  168
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65547.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': 6, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   8
# Current state:  208
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65548.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': '6', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   9
# Current state:  248
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65549.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': '6', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   10
# Current state:  249
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65550.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': 7, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   10
# Current state:  250
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65551.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': 8, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   10
# Current state:  290
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65552.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': 9, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   10
# Current state:  330
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65553.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': 10, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   10
# Current state:  370
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65554.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 11, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   10
# Current state:  410
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65555.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': '11', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   11
# Current state:  450
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65556.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 12, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   11
# Current state:  451
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65557.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 13, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   11
# Current state:  491
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65558.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 14, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   11
# Current state:  531
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65559.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 15, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   11
# Current state:  571
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65560.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 16, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   11
# Current state:  611
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65561.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '16', 'y': 12}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   12
# Current state:  651
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65562.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '16', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   11
# Current state:  652
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65563.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 17, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  17   11
# Current state:  651
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  65564.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1000, 'scoreIncrement': 22.53, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 2, 'runId': '52373', 'reward': 1000, 'scoreIncrement': 22.53, 'newState': None}
# 2  ended
# 2  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52374', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  66565.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52374', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  66566.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '52374', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  66567.0

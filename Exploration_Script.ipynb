# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=7
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1

        while True:
            
            
            
            # Choose action using epsilon-greedy strategy
            
#             action = np.argmax(Q[world_id, state])
            if random.uniform(0, 1) <= adjusted_epsilon:
                while True:
                    a = random.randint(0, 3)
                    if Q[world_id, state, a]!= np.argmin(Q[world_id, state]) or Q[world_id, state, a]==0:
                        action=a
                        break

        
#                 for a in range(n_actions):
#                     if Q[world_id, state, a]==0:
#                         action=a
#                         break
            else :
                action=np.argmax(Q[world_id, state])
                        
#                         while True:
#                             a = random.randint(0, 3)
#                             if Q[world_id, state, a]!= np.argmin(Q[world_id, state]):
#                                 action=a
#                                 break
                        

#             else:

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                print("Last action to terminal: ", action )
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        
        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        if reward>0:
            break
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# # Print the learned policy
# for world_id in range(n_worlds):
#     print(f"World {world_id}:")
#     for state in range(n_states):
#         print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.   3.   2.   2. 186.  34. 147.  32.   2.   2.   2.]
# 7  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310372.00000000204
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.09, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310372.100000002
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.08, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310372.200000002
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.07, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310372.30000000197
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.07, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   3
# Current state:  3
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310372.40000000194
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.06, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   2
# Current state:  43
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310372.5000000019
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.05, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   1
# Current state:  42
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310372.6000000019
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.05, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310372.7000000019
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.04, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310372.80000000185
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.04, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310372.9000000018
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.03, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310373.0000000018
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.03, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   0
# Current state:  80
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310373.1000000018
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.03, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310373.20000000176
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.03, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310373.30000000173
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.02, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310373.4000000017
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.02, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   1
# Current state:  82
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310373.5000000017
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.02, 'newState': {'x': '2', 'y': 0}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   0
# Current state:  81
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310373.60000000166
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.02, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   0
# Current state:  80
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310373.70000000164
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.02, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   0
# Current state:  40
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310373.8000000016
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.01, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310373.9000000016
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.01, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   1
# Current state:  80
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310374.0000000016
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.01, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310374.10000000155
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.01, 'newState': {'x': '2', 'y': 3}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   3
# Current state:  82
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310374.2000000015
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.01, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   2
# Current state:  83
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310374.3000000015
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.01, 'newState': {'x': 1, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   2
# Current state:  82
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310374.4000000015
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.01, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   1
# Current state:  42
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310374.50000000146
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.01, 'newState': {'x': 0, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  0   1
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310374.60000000143
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.01, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310374.7000000014
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': -0.01, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310374.8000000014
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 3}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   3
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310374.90000000136
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   3
# Current state:  43
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310375.00000000134
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   3
# Current state:  83
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310375.1000000013
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '1', 'y': 4}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   4
# Current state:  43
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310375.2000000013
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   4
# Current state:  44
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310375.30000000127
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 3, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  3   4
# Current state:  84
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310375.40000000125
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  4   4
# Current state:  124
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310375.5000000012
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 5}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  4   5
# Current state:  164
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310375.6000000012
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  5   5
# Current state:  165
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310375.7000000012
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '5', 'y': 6}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  5   6
# Current state:  205
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310375.80000000115
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  4   6
# Current state:  206
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310375.90000000113
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 3, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  3   6
# Current state:  166
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310376.0000000011
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '3', 'y': 7}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  3   7
# Current state:  126
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310376.1000000011
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '3', 'y': 6}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  3   6
# Current state:  127
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310376.20000000106
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   6
# Current state:  126
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310376.30000000104
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '2', 'y': 5}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   5
# Current state:  86
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310376.400000001
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 3, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  3   5
# Current state:  85
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310376.500000001
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   5
# Current state:  125
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310376.60000000097
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '2', 'y': 4}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   4
# Current state:  85
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310376.70000000094
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 1, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  1   4
# Current state:  84
# Taken action to come to the current state from the previous state:  3
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310376.8000000009
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 2, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  2   4
# Current state:  44
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310376.9000000009
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 3, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  3   4
# Current state:  84
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310377.0000000009
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '3', 'y': 3}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  3   3
# Current state:  124
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310377.10000000085
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '3', 'y': 2}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  3   2
# Current state:  123
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310377.2000000008
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  4   2
# Current state:  122
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310377.3000000008
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 1}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  4   1
# Current state:  162
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310377.4000000008
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  3   1
# Current state:  161
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310377.50000000076
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '3', 'y': 2}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  3   2
# Current state:  121
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310377.60000000073
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  4   2
# Current state:  122
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310377.7000000007
# printing the response:
#  {'code': 'OK', 'worldId': 7, 'runId': '50879', 'reward': -0.1, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 1}}
# Visual of the given details is printed above
# World Number:  7
# Current state row and column:  4   1
# Current state:  162
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -0.1
# cumulative reward from the world so far:  -310377.8000000007

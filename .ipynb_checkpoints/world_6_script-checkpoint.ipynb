# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=6
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1
        next_state_row, next_state_col=0,0

        while True:
            while True:


                if next_state_row==20 and next_state_col==30:
                    action=1
                    action = np.argmax(Q[world_id, state])


                # Choose action using epsilon-greedy strategy

    #             action = np.argmax(Q[world_id, state])
                elif random.uniform(0, 1) <= adjusted_epsilon:
                    if next_state_row != 20:
                        if next_state_row<20:
                            action=2
                        elif next_state_row>20:
                            action=3


                elif next_state_col!=30:
                    if next_state_col<30:
                        action=0
                    elif next_state_col>30:
                        action=1     
    #             elif:
    #                 state_row==20 and state_col==30:
    #                 action=1
    #                 action = np.argmax(Q[world_id, state])

                if Q[world_id, state, action]!= np.argmin(Q[world_id, state]) or Q[world_id, state, action]==0:
                    break

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.   3.   2.   2. 186.   7. 132.   2.   2.   2.   2.]
# 6  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.1, 'scoreIncrement': 0.1, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  35764.8600000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.1, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35764.9700000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.09, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35765.0800000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.08, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35765.1900000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.07, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35765.3000000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.07, 'newState': {'x': 4, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   2
# Current state:  122
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35765.420000003905
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.06, 'newState': {'x': '4', 'y': 1}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   1
# Current state:  162
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35765.530000003906
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.06, 'newState': {'x': 5, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  5   1
# Current state:  161
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35765.65000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': 6, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  6   1
# Current state:  201
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35765.77000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.05, 'newState': {'x': 5, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  5   1
# Current state:  241
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35765.890000003914
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.04, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   1
# Current state:  201
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35766.000000003914
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.04, 'newState': {'x': '4', 'y': 2}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   2
# Current state:  161
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35766.12000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.03, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  3   2
# Current state:  162
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35766.23000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.03, 'newState': {'x': '3', 'y': 1}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  3   1
# Current state:  122
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35766.34000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.03, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  2   1
# Current state:  121
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35766.45000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.02, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   1
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35766.56000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.1, 'scoreIncrement': 0.02, 'newState': {'x': '1', 'y': 0}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   0
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  35766.66000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.1, 'scoreIncrement': 0.02, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  0   0
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.1
# cumulative reward from the world so far:  35766.76000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.1, 'scoreIncrement': 0.02, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.1
# cumulative reward from the world so far:  35766.860000003915
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.1, 'scoreIncrement': 0.01, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.1
# cumulative reward from the world so far:  35766.96000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': '1', 'y': 1}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   1
# Current state:  40
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35767.070000003914
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35767.180000003915
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35767.290000003915
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': '2', 'y': 3}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  2   3
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35767.400000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.01, 'newState': {'x': '2', 'y': 4}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  2   4
# Current state:  83
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35767.52000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.11, 'scoreIncrement': 0.01, 'newState': {'x': '2', 'y': 3}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  2   3
# Current state:  84
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.11
# cumulative reward from the world so far:  35767.63000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.01, 'newState': {'x': 3, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  3   3
# Current state:  83
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35767.75000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.01, 'newState': {'x': 4, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   3
# Current state:  123
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35767.870000003924
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.01, 'newState': {'x': 3, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  3   3
# Current state:  163
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35767.99000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.01, 'newState': {'x': '3', 'y': 4}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  3   4
# Current state:  123
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35768.11000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.12, 'scoreIncrement': 0.01, 'newState': {'x': 4, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   4
# Current state:  124
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.12
# cumulative reward from the world so far:  35768.23000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.13, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 5}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   5
# Current state:  164
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  35768.36000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.13, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 6}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   6
# Current state:  165
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  35768.49000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.13, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 7}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   7
# Current state:  166
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  35768.620000003924
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.14, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  5   7
# Current state:  167
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  35768.760000003924
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.13, 'scoreIncrement': 0, 'newState': {'x': 4, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   7
# Current state:  207
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.13
# cumulative reward from the world so far:  35768.89000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.13, 'scoreIncrement': 0, 'newState': {'x': '4', 'y': 6}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  4   6
# Current state:  167
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  35769.02000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.13, 'scoreIncrement': 0, 'newState': {'x': 5, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  5   6
# Current state:  166
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.13
# cumulative reward from the world so far:  35769.150000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.14, 'scoreIncrement': 0, 'newState': {'x': 6, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  6   6
# Current state:  206
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  35769.290000003915
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.14, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 7}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  6   7
# Current state:  246
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  35769.430000003915
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.14, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 8}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  6   8
# Current state:  247
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.14
# cumulative reward from the world so far:  35769.570000003914
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.14, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 7}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  6   7
# Current state:  248
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  35769.71000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.14, 'scoreIncrement': 0, 'newState': {'x': '6', 'y': 8}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  6   8
# Current state:  247
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.14
# cumulative reward from the world so far:  35769.85000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.15, 'scoreIncrement': 0, 'newState': {'x': 7, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  7   8
# Current state:  248
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.15
# cumulative reward from the world so far:  35770.000000003914
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.15, 'scoreIncrement': 0, 'newState': {'x': '7', 'y': 9}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  7   9
# Current state:  288
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.15
# cumulative reward from the world so far:  35770.150000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 8, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  8   9
# Current state:  289
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35770.31000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '8', 'y': 10}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  8   10
# Current state:  329
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35770.47000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': 7, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  7   10
# Current state:  330
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35770.63000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.16, 'scoreIncrement': 0, 'newState': {'x': '7', 'y': 11}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  7   11
# Current state:  290
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.16
# cumulative reward from the world so far:  35770.79000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': 8, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  8   11
# Current state:  291
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35770.96000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.17, 'scoreIncrement': 0, 'newState': {'x': 9, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  9   11
# Current state:  331
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.17
# cumulative reward from the world so far:  35771.13000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.18, 'scoreIncrement': 0, 'newState': {'x': '9', 'y': 12}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  9   12
# Current state:  371
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.18
# cumulative reward from the world so far:  35771.31000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': 10, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  10   12
# Current state:  372
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  35771.50000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '10', 'y': 13}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  10   13
# Current state:  412
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  35771.69000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.2, 'scoreIncrement': 0, 'newState': {'x': 11, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  11   13
# Current state:  413
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.2
# cumulative reward from the world so far:  35771.89000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.21, 'scoreIncrement': 0, 'newState': {'x': 12, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  12   13
# Current state:  453
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.21
# cumulative reward from the world so far:  35772.10000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': 13, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  13   13
# Current state:  493
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.22
# cumulative reward from the world so far:  35772.32000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.21, 'scoreIncrement': 0, 'newState': {'x': 12, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  12   13
# Current state:  533
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.21
# cumulative reward from the world so far:  35772.53000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': '12', 'y': 14}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  12   14
# Current state:  493
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  35772.75000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': '12', 'y': 15}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  12   15
# Current state:  494
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.23
# cumulative reward from the world so far:  35772.98000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': 13, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  13   15
# Current state:  495
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.24
# cumulative reward from the world so far:  35773.22000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': 14, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  14   15
# Current state:  535
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.25
# cumulative reward from the world so far:  35773.47000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': 15, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  15   15
# Current state:  575
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.26
# cumulative reward from the world so far:  35773.73000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.28, 'scoreIncrement': 0, 'newState': {'x': '15', 'y': 16}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  15   16
# Current state:  615
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.28
# cumulative reward from the world so far:  35774.01000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': 14, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  14   16
# Current state:  616
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.26
# cumulative reward from the world so far:  35774.27000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.28, 'scoreIncrement': 0, 'newState': {'x': 15, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  15   16
# Current state:  576
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.28
# cumulative reward from the world so far:  35774.55000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.29, 'scoreIncrement': 0, 'newState': {'x': '15', 'y': 17}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  15   17
# Current state:  616
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.29
# cumulative reward from the world so far:  35774.84000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.28, 'scoreIncrement': 0, 'newState': {'x': 14, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  14   17
# Current state:  617
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.28
# cumulative reward from the world so far:  35775.12000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.29, 'scoreIncrement': 0, 'newState': {'x': 15, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  15   17
# Current state:  577
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.29
# cumulative reward from the world so far:  35775.41000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.31, 'scoreIncrement': 0, 'newState': {'x': 16, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  16   17
# Current state:  617
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.31
# cumulative reward from the world so far:  35775.72000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.33, 'scoreIncrement': 0, 'newState': {'x': '16', 'y': 18}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  16   18
# Current state:  657
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.33
# cumulative reward from the world so far:  35776.05000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.36, 'scoreIncrement': 0, 'newState': {'x': '16', 'y': 19}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  16   19
# Current state:  658
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.36
# cumulative reward from the world so far:  35776.41000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.38, 'scoreIncrement': 0, 'newState': {'x': 17, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  17   19
# Current state:  659
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.38
# cumulative reward from the world so far:  35776.79000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.42, 'scoreIncrement': 0, 'newState': {'x': 18, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  18   19
# Current state:  699
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.42
# cumulative reward from the world so far:  35777.21000000393
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.38, 'scoreIncrement': 0, 'newState': {'x': '18', 'y': 18}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  18   18
# Current state:  739
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.38
# cumulative reward from the world so far:  35777.590000003926
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.42, 'scoreIncrement': 0, 'newState': {'x': 19, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  19   18
# Current state:  738
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.42
# cumulative reward from the world so far:  35778.010000003924
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': 20, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  20   18
# Current state:  778
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.45
# cumulative reward from the world so far:  35778.46000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': '20', 'y': 19}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  20   19
# Current state:  818
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35778.96000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': 21, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   19
# Current state:  819
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.56
# cumulative reward from the world so far:  35779.52000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': 22, 'y': '19'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   19
# Current state:  859
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.63
# cumulative reward from the world so far:  35780.150000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.71, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 20}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   20
# Current state:  899
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.71
# cumulative reward from the world so far:  35780.860000003915
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': '22', 'y': 21}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   21
# Current state:  900
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  35781.69000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.71, 'scoreIncrement': 0, 'newState': {'x': 21, 'y': '21'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   21
# Current state:  901
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.71
# cumulative reward from the world so far:  35782.400000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': '21', 'y': 22}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   22
# Current state:  861
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  35783.23000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 22, 'y': '22'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   22
# Current state:  862
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35784.23000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': 23, 'y': '22'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  23   22
# Current state:  902
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.25
# cumulative reward from the world so far:  35785.48000000392
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1.67, 'scoreIncrement': 0, 'newState': {'x': '23', 'y': 23}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  23   23
# Current state:  942
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.67
# cumulative reward from the world so far:  35787.150000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': 22, 'y': '23'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   23
# Current state:  943
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.25
# cumulative reward from the world so far:  35788.400000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': 21, 'y': '23'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   23
# Current state:  903
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35789.400000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': '21', 'y': 24}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   24
# Current state:  863
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.25
# cumulative reward from the world so far:  35790.650000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '21', 'y': 25}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  21   25
# Current state:  864
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35791.650000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': 22, 'y': '25'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  22   25
# Current state:  865
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.25
# cumulative reward from the world so far:  35792.900000003916
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1.67, 'scoreIncrement': 0, 'newState': {'x': 23, 'y': '25'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  23   25
# Current state:  905
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.67
# cumulative reward from the world so far:  35794.570000003914
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 2.5, 'scoreIncrement': 0, 'newState': {'x': 24, 'y': '25'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   25
# Current state:  945
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  2.5
# cumulative reward from the world so far:  35797.070000003914
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1.67, 'scoreIncrement': 0, 'newState': {'x': 23, 'y': '25'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  23   25
# Current state:  985
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.67
# cumulative reward from the world so far:  35798.74000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 2.5, 'scoreIncrement': 0, 'newState': {'x': 24, 'y': '25'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   25
# Current state:  945
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  2.5
# cumulative reward from the world so far:  35801.24000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1.67, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 26}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   26
# Current state:  985
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.67
# cumulative reward from the world so far:  35802.91000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1.25, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 27}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   27
# Current state:  986
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.25
# cumulative reward from the world so far:  35804.16000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 1, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 28}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   28
# Current state:  987
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  35805.16000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.83, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 29}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   29
# Current state:  988
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.83
# cumulative reward from the world so far:  35805.99000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.71, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 30}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   30
# Current state:  989
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.71
# cumulative reward from the world so far:  35806.70000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 31}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   31
# Current state:  990
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.63
# cumulative reward from the world so far:  35807.33000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.71, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 30}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  24   30
# Current state:  991
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.71
# cumulative reward from the world so far:  35808.04000000391
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': 25, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  25   30
# Current state:  990
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.63
# cumulative reward from the world so far:  35808.670000003905
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': 26, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   30
# Current state:  1030
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.56
# cumulative reward from the world so far:  35809.2300000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': '26', 'y': 31}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   31
# Current state:  1070
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35809.7300000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': '26', 'y': 32}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   32
# Current state:  1071
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.45
# cumulative reward from the world so far:  35810.1800000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': '26', 'y': 31}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   31
# Current state:  1072
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35810.6800000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': 27, 'y': '31'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  27   31
# Current state:  1071
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.45
# cumulative reward from the world so far:  35811.1300000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': '27', 'y': 30}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  27   30
# Current state:  1111
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35811.6300000039
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': '27', 'y': 29}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  27   29
# Current state:  1110
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.56
# cumulative reward from the world so far:  35812.190000003895
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.63, 'scoreIncrement': 0, 'newState': {'x': 26, 'y': '29'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   29
# Current state:  1109
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.63
# cumulative reward from the world so far:  35812.82000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.56, 'scoreIncrement': 0, 'newState': {'x': '26', 'y': 30}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  26   30
# Current state:  1069
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.56
# cumulative reward from the world so far:  35813.38000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.5, 'scoreIncrement': 0, 'newState': {'x': 27, 'y': '30'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  27   30
# Current state:  1070
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.5
# cumulative reward from the world so far:  35813.88000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.45, 'scoreIncrement': 0, 'newState': {'x': '27', 'y': 31}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  27   31
# Current state:  1110
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.45
# cumulative reward from the world so far:  35814.33000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.42, 'scoreIncrement': 0, 'newState': {'x': '27', 'y': 32}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  27   32
# Current state:  1111
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.42
# cumulative reward from the world so far:  35814.750000003885
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.38, 'scoreIncrement': 0, 'newState': {'x': 28, 'y': '32'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  28   32
# Current state:  1112
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.38
# cumulative reward from the world so far:  35815.13000000388
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.36, 'scoreIncrement': 0, 'newState': {'x': 29, 'y': '32'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  29   32
# Current state:  1152
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.36
# cumulative reward from the world so far:  35815.49000000388
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.33, 'scoreIncrement': 0, 'newState': {'x': 30, 'y': '32'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  30   32
# Current state:  1192
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.33
# cumulative reward from the world so far:  35815.820000003885
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.31, 'scoreIncrement': 0, 'newState': {'x': '30', 'y': 33}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  30   33
# Current state:  1232
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.31
# cumulative reward from the world so far:  35816.13000000388
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.29, 'scoreIncrement': 0, 'newState': {'x': '30', 'y': 34}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  30   34
# Current state:  1233
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.29
# cumulative reward from the world so far:  35816.42000000388
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.31, 'scoreIncrement': 0, 'newState': {'x': 29, 'y': '34'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  29   34
# Current state:  1234
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.31
# cumulative reward from the world so far:  35816.73000000388
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.29, 'scoreIncrement': 0, 'newState': {'x': '29', 'y': 35}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  29   35
# Current state:  1194
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.29
# cumulative reward from the world so far:  35817.02000000388
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.28, 'scoreIncrement': 0, 'newState': {'x': '29', 'y': 36}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  29   36
# Current state:  1195
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.28
# cumulative reward from the world so far:  35817.30000000388
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.26, 'scoreIncrement': 0, 'newState': {'x': '29', 'y': 37}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  29   37
# Current state:  1196
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.26
# cumulative reward from the world so far:  35817.56000000388
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.25, 'scoreIncrement': 0, 'newState': {'x': '29', 'y': 38}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  29   38
# Current state:  1197
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.25
# cumulative reward from the world so far:  35817.81000000388
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.24, 'scoreIncrement': 0, 'newState': {'x': 30, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  30   38
# Current state:  1198
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.24
# cumulative reward from the world so far:  35818.05000000388
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': '30', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  30   39
# Current state:  1238
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.23
# cumulative reward from the world so far:  35818.280000003884
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': 31, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  31   39
# Current state:  1239
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.22
# cumulative reward from the world so far:  35818.500000003885
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.23, 'scoreIncrement': 0, 'newState': {'x': '31', 'y': 38}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  31   38
# Current state:  1279
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.23
# cumulative reward from the world so far:  35818.73000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': '31', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  31   39
# Current state:  1278
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.22
# cumulative reward from the world so far:  35818.95000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.22, 'scoreIncrement': 0, 'newState': {'x': '31', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  31   39
# Current state:  1279
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.22
# cumulative reward from the world so far:  35819.17000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.21, 'scoreIncrement': 0, 'newState': {'x': 32, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  32   39
# Current state:  1279
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.21
# cumulative reward from the world so far:  35819.38000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.2, 'scoreIncrement': 0, 'newState': {'x': 33, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  33   39
# Current state:  1319
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.2
# cumulative reward from the world so far:  35819.58000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': 34, 'y': '39'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  34   39
# Current state:  1359
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  35819.77000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 39}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  34   39
# Current state:  1399
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  35819.96000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.2, 'scoreIncrement': 0, 'newState': {'x': '34', 'y': 38}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  34   38
# Current state:  1399
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.2
# cumulative reward from the world so far:  35820.16000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': 35, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  35   38
# Current state:  1398
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  0.19
# cumulative reward from the world so far:  35820.35000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': 36, 'y': '38'}}
# Visual of the given details is printed above
# World Number:  6
# Current state row and column:  36   38
# Current state:  1438
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  0.19
# cumulative reward from the world so far:  35820.54000000389
# printing the response:
#  {'code': 'OK', 'worldId': 6, 'runId': '50792', 'reward': 0.19, 'scoreIncrement': 0, 'newState': {'x': 35, 'y': '38'}}

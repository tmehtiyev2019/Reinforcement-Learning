# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=9
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1
        next_state_row, next_state_col=0,0

        while True:
            while True:


                if next_state_row==17 and next_state_col==11:
                    action=1
                    action = np.argmax(Q[world_id, state])


                # Choose action using epsilon-greedy strategy

    #             action = np.argmax(Q[world_id, state])
                elif random.uniform(0, 1) <= adjusted_epsilon:
                    if next_state_row != 17:
                        if next_state_row<17:
                            action=2
                        elif next_state_row>17:
                            action=3


                elif next_state_col!=11:
                    if next_state_col<11:
                        action=0
                    elif next_state_col>11:
                        action=1     
    #             elif:
    #                 state_row==20 and state_col==30:
    #                 action=1
    #                 action = np.argmax(Q[world_id, state])

                if Q[world_id, state, action]!= np.argmin(Q[world_id, state]) or Q[world_id, state, action]==0:
                    break

#                 action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.  77.   9.   2. 186.  34. 147.  37.   9.   2.   2.]
# 2  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44710.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   2
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44711.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   3
# Current state:  2
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44712.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 1, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   3
# Current state:  3
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44713.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 2, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   3
# Current state:  43
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44714.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 3, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   3
# Current state:  83
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44715.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 2, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   3
# Current state:  123
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44716.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 3, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   3
# Current state:  83
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44717.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '3', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   4
# Current state:  123
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44718.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 4, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   4
# Current state:  124
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44719.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '4', 'y': 5}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   5
# Current state:  164
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44720.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '4', 'y': 6}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   6
# Current state:  165
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44721.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': '4', 'y': 5}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   5
# Current state:  166
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44722.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '4', 'y': 6}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   6
# Current state:  165
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44723.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': 5, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   6
# Current state:  166
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44724.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': '5', 'y': 7}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   7
# Current state:  206
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44725.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 6, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   7
# Current state:  207
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44726.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': '6', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   8
# Current state:  247
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44727.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': 7, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   8
# Current state:  248
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44728.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': 8, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   8
# Current state:  288
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44729.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': 9, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   8
# Current state:  328
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44730.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': '9', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   9
# Current state:  368
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44731.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': '9', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   10
# Current state:  369
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44732.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': 10, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   10
# Current state:  370
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44733.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': 9, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   10
# Current state:  410
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44734.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': 10, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   10
# Current state:  370
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44735.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 11, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   10
# Current state:  410
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44736.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 12, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   10
# Current state:  450
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44737.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 11, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   10
# Current state:  490
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44738.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': '11', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   11
# Current state:  450
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44739.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 12, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   11
# Current state:  451
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44740.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 13, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   11
# Current state:  491
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44741.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '13', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   10
# Current state:  531
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44742.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '13', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   11
# Current state:  530
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44743.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '13', 'y': 12}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   12
# Current state:  531
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44744.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '13', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   11
# Current state:  532
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44745.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': 12, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   11
# Current state:  531
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44746.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': '12', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   10
# Current state:  491
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44747.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': '12', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   11
# Current state:  490
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44748.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.02, 'newState': {'x': 13, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   11
# Current state:  491
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44749.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 14, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   11
# Current state:  531
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44750.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 15, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   11
# Current state:  571
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44751.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '15', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   10
# Current state:  611
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44752.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 16, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   10
# Current state:  610
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44753.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '16', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   11
# Current state:  650
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44754.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '16', 'y': 12}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   12
# Current state:  651
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44755.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': 17, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  17   12
# Current state:  652
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44756.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1, 'scoreIncrement': 0.01, 'newState': {'x': '17', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  17   11
# Current state:  692
# Taken action to come to the current state from the previous state:  1
# Reward of the current state:  1.0
# cumulative reward from the world so far:  44757.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1000, 'scoreIncrement': 6.36, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 2, 'runId': '51740', 'reward': 1000, 'scoreIncrement': 6.36, 'newState': None}
# 2  ended
# [  0.  77.  10.   2. 186.  34. 147.  37.   9.   2.   2.]
# 2  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45758.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   0
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45759.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45760.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45761.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45762.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45763.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   1
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45764.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': '4', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   2
# Current state:  161
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45765.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': 5, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   2
# Current state:  162
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45766.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': '5', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   3
# Current state:  202
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45767.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': 6, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   3
# Current state:  203
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45768.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '6', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   4
# Current state:  243
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45769.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': 7, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   4
# Current state:  244
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45770.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '7', 'y': 5}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   5
# Current state:  284
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45771.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': '7', 'y': 6}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   6
# Current state:  285
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45772.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': 8, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   6
# Current state:  286
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45773.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 7, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   6
# Current state:  326
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45774.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': '7', 'y': 7}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   7
# Current state:  286
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45775.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': 8, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   7
# Current state:  287
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45776.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': '8', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   8
# Current state:  327
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45777.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': '8', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   9
# Current state:  328
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45778.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': '8', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   10
# Current state:  329
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45779.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': 9, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   10
# Current state:  330
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45780.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': '9', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   11
# Current state:  370
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45781.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': '9', 'y': 12}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   12
# Current state:  371
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45782.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': 10, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   12
# Current state:  372
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45783.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 11, 'y': '12'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   12
# Current state:  412
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45784.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': '11', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   11
# Current state:  452
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45785.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 12, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   11
# Current state:  451
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45786.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 13, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   11
# Current state:  491
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45787.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 14, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   11
# Current state:  531
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45788.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 15, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   11
# Current state:  571
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45789.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 16, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   11
# Current state:  611
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45790.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 17, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  17   11
# Current state:  651
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  45791.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1000, 'scoreIncrement': 27.81, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 2, 'runId': '51742', 'reward': 1000, 'scoreIncrement': 27.81, 'newState': None}
# 2  ended
# [  0.  77.  11.   2. 186.  34. 147.  37.   9.   2.   2.]
# 2  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': '0', 'y': 0}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46792.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46793.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46794.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46795.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   1
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46796.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 2, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   1
# Current state:  41
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46797.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '2', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   2
# Current state:  81
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46798.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46799.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '3', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   3
# Current state:  122
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46800.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 4, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   3
# Current state:  123
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46801.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': 5, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   3
# Current state:  163
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46802.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '5', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   4
# Current state:  203
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46803.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': 6, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   4
# Current state:  204
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46804.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '6', 'y': 5}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   5
# Current state:  244
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46805.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': '6', 'y': 6}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   6
# Current state:  245
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46806.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': 7, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   6
# Current state:  246
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46807.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': '7', 'y': 7}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   7
# Current state:  286
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46808.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': '7', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   8
# Current state:  287
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46809.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': '7', 'y': 7}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   7
# Current state:  288
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46810.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': 8, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   7
# Current state:  287
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46811.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': 9, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   7
# Current state:  327
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46812.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': 10, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   7
# Current state:  367
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46813.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': '10', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   8
# Current state:  407
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46814.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': 11, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   8
# Current state:  408
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46815.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': '11', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   9
# Current state:  448
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46816.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': '11', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   10
# Current state:  449
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46817.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': '11', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   11
# Current state:  450
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46818.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 12, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   11
# Current state:  451
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46819.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 13, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   11
# Current state:  491
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46820.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 14, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   11
# Current state:  531
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  46821.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51743', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 15, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   11
# Current state:  571
# ...
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52035.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': '12', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   8
# Current state:  487
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52036.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': '12', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   9
# Current state:  488
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52037.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.06, 'newState': {'x': 13, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   9
# Current state:  489
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52038.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': '13', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  13   10
# Current state:  529
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52039.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.05, 'newState': {'x': 14, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  14   10
# Current state:  530
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52040.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': 15, 'y': '10'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   10
# Current state:  570
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52041.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.04, 'newState': {'x': '15', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   9
# Current state:  610
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52042.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '15', 'y': 10}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   10
# Current state:  609
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52043.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': '15', 'y': 11}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  15   11
# Current state:  610
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52044.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 16, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  16   11
# Current state:  611
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52045.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1, 'scoreIncrement': 0.03, 'newState': {'x': 17, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  17   11
# Current state:  651
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  52046.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1000, 'scoreIncrement': 22.53, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 2, 'runId': '51750', 'reward': 1000, 'scoreIncrement': 22.53, 'newState': None}
# 2  ended
# [  0.  77.  17.   2. 186.  34. 147.  37.   9.   2.   2.]
# 2  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 1, 'newState': {'x': 0, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  0   0
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53047.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.9, 'newState': {'x': 1, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  1   0
# Current state:  0
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53048.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.81, 'newState': {'x': 2, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  2   0
# Current state:  40
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53049.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.73, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   0
# Current state:  80
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53050.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.66, 'newState': {'x': 4, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   0
# Current state:  120
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53051.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.59, 'newState': {'x': 3, 'y': '0'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   0
# Current state:  160
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53052.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.53, 'newState': {'x': '3', 'y': 1}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  3   1
# Current state:  120
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53053.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.48, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   1
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53054.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.43, 'newState': {'x': '4', 'y': 2}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  4   2
# Current state:  161
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53055.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.39, 'newState': {'x': 5, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   2
# Current state:  162
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53056.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.35, 'newState': {'x': '5', 'y': 3}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   3
# Current state:  202
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53057.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.31, 'newState': {'x': '5', 'y': 4}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  5   4
# Current state:  203
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53058.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.28, 'newState': {'x': 6, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   4
# Current state:  204
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53059.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.25, 'newState': {'x': '6', 'y': 5}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  6   5
# Current state:  244
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53060.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.23, 'newState': {'x': 7, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   5
# Current state:  245
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53061.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.21, 'newState': {'x': '7', 'y': 6}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  7   6
# Current state:  285
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53062.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.19, 'newState': {'x': 8, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  8   6
# Current state:  286
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53063.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.17, 'newState': {'x': 9, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   6
# Current state:  326
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53064.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.15, 'newState': {'x': 10, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   6
# Current state:  366
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53065.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.14, 'newState': {'x': '10', 'y': 7}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   7
# Current state:  406
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53066.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.12, 'newState': {'x': 9, 'y': '7'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   7
# Current state:  407
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53067.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.11, 'newState': {'x': '9', 'y': 8}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  9   8
# Current state:  367
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53068.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.1, 'newState': {'x': 10, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  10   8
# Current state:  368
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53069.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.09, 'newState': {'x': 11, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   8
# Current state:  408
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53070.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.08, 'newState': {'x': '11', 'y': 9}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  11   9
# Current state:  448
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53071.0
# printing the response:
#  {'code': 'OK', 'worldId': 2, 'runId': '51752', 'reward': 1, 'scoreIncrement': 0.07, 'newState': {'x': 12, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  2
# Current state row and column:  12   9
# Current state:  449
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  1.0
# cumulative reward from the world so far:  53072.0

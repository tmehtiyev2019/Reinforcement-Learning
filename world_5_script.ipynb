# %%
import matplotlib.pyplot as plt
import http.client
import json
import numpy as np
import random
import time
import ssl
import subprocess

# Working directory
wd='C:/Users/eljanmuhammed/Documents/Git/Reinforcement-Learning' #please change before running the program

fi='C:/git_update.bat'

# API Inputs
api_key = "13d493c2d91efe1c451a"
user_id = "1171"
team_id = "1343"
base_url = "www.notexponential.com"
otp=5712768807

headers = {
  'x-api-key': '13d493c2d91efe1c451a', 
  'userid': '1171', 
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic YWxpLmFzZ2Fyb3ZAZ3dtYWlsLmd3dS5lZHU6TWFydmVsMDc0QA=='
}

n_worlds = 11
start_world=1
end_world=11
world_size = 40
n_states = world_size * world_size
n_actions = 4
n_episodes = 10
alpha = 0.9
gamma = 0.99
epsilon = .5
minimum_traversal_requirement=5

# Initialize the Q-table, reward_map, world_traversal_count
Q= np.load(f"{wd}/Q.npy")
reward_map= np.load(f"{wd}/reward_map.npy")
world_traversal_count= np.load(f"{wd}/world_traversal_count.npy")





# Create an SSL context with verification disabled
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE



# Reset Api
def reset_api():
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    payload = ''
    conn.request("GET", f"/aip2pgaming/api/rl/reset.php?teamId={team_id}&otp={otp}", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))


# Define a function to send a request
def send_request(method, path, headers, body=None):
    conn = http.client.HTTPSConnection(base_url, context=ssl_context)
    conn.request(method, path, body, headers)
    response = conn.getresponse()
    data = response.read().decode('utf-8')
    conn.close()
    return json.loads(data)

# Define a function to enter a world
def enter_world(world_id):
    data = f"type=enter&worldId={world_id}&teamId={team_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)

# Define a function to make a move
def make_move(world_id, move):
    if move==0:
        move='N'
    elif move==1:
        move='S'
    elif move==2:
        move='E'
    elif move==3:
        move='W'
        
    data = f"type=move&teamId={team_id}&move={move}&worldId={world_id}"
    return send_request("POST", "/aip2pgaming/api/rl/gw.php", headers, data)
# Define a function to visualize the grid world
def plot_world(world_data):
    plt.imshow(world_data, cmap='binary')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# Main loop
for episode in range(n_episodes):
    print(episode, " episode started")

    for world_number in range(n_worlds):
        
        if min(world_traversal_count[1:])<minimum_traversal_requirement:
            world_id=np.argmin(world_traversal_count[1:])+1
            print(world_traversal_count)
        else:
            world_id=np.argmax(score_map[1:])+1
            print(score_map)

        world_id=5
        adjusted_epsilon=epsilon*(1**world_traversal_count[world_id])
        adjusted_alpha=alpha*(1**world_traversal_count[world_id])
        print(world_id, " world selected for iteration")
        print("learning rate alpha", adjusted_alpha)
        print("exploration rate epsilon", adjusted_epsilon)
        
        while True:
            try:
                reset_api()
                break
            except:
                time.sleep(60*10)
                
        while True:
            try:
                enter_resp = enter_world(world_id)
                break
            except:
                 time.sleep(60*10)
        score_map= np.load(f'{wd}/score_map_{world_id}.npy')
        world_data = np.zeros((world_size, world_size))

        # Get the initial state
        state_row, state_col = map(int, enter_resp["state"].split(':'))
        state = state_row * world_size + state_col
        world_data[state_row, state_col] = 1
        score_map[state_row, state_col]=1

        while True:
            
            
            # Choose action using epsilon-greedy strategy
            
#             action = np.argmax(Q[world_id, state])
            if random.uniform(0, 1) <= adjusted_epsilon:
                if state_row!=12:
                    if state_row<12:
                        action=2
                    elif state_row>12:
                        action=1
                        

            else:
                if state_col!=18:
                    if state_col<18:
                        action=0
                    elif state_col>18:
                        action=3      
            if state_row==12 and state_col==18:
                action=0
        

                action = np.argmax(Q[world_id, state])

            # Make a move and get the reward and next state
            while True:
                try: 
                    move_resp = make_move(world_id, action)
                    break
                except:
                    time.sleep(10 * 60)
                
            print("printing the response: \n", move_resp)
            reward = float(move_resp["reward"])
            reward_map[world_id]=reward_map[world_id]+reward

            # Get the next state
            try:
                next_state_row, next_state_col = int(move_resp["newState"]["x"]), int(move_resp["newState"]["y"])
                next_state = next_state_row * world_size + next_state_col
                world_data[next_state_row, next_state_col] = 1
                score_map[next_state_row, next_state_col]=1
            except:
                print("test except")
                print("printing before terminal state: \n", move_resp)
                # If there is an error, the game is over
                Q[world_id, state, action] += adjusted_alpha * (reward - Q[world_id, state, action])
                np.save(f'{wd}/Q.npy', Q)
                np.save(f'{wd}/score_map_{world_id}.npy', score_map)
                np.save(f'{wd}/reward_map.npy', reward_map)
                break

            # Update Q-table
            Q[world_id, state, action] += adjusted_alpha * (reward + gamma * np.max(Q[world_id, next_state]) - Q[world_id, state, action])
            np.save(f'{wd}/Q.npy', Q)
            np.save(f'{wd}/score_map_{world_id}.npy', score_map)
            np.save(f'{wd}/reward_map.npy', reward_map)
            


            # Visualize the grid world
            plot_world(world_data)
            print("Visual of the given details is printed above ")
            print("World Number: ", world_id )
            print("Current state row and column: ", next_state_row, " ",next_state_col )
            print("Current state: ", state )
            print("Taken action to come to the current state from the previous state: ", action )
            print("Reward of the current state: ", reward)
            print("cumulative reward from the world so far: ", reward_map[world_id])

            # Move to the next state
            state = next_state

            # Introduce a delay before the next action
            time.sleep(0.5)

        world_traversal_count[world_id]=world_traversal_count[world_id]+1
        subprocess.call([fi]) #
        np.save(f'{wd}/world_traversal_count.npy', world_traversal_count)
        print(world_id, " ended")
        # Introduce a delay before entering the next world
#         time.sleep(10 * 60)
        

# Print the learned policy
for world_id in range(n_worlds):
    print(f"World {world_id}:")
    for state in range(n_states):
        print(f"  In state {state}, take action: {np.argmax(Q[world_id, state])}")
# Out:
# 0  episode started
# [  0.   3.   2.   2. 186.   5.   2.   2.   2.   2.   2.]
# 5  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289059.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289060.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289061.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289062.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': 3, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   2
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289063.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': 4, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   2
# Current state:  122
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289064.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': '4', 'y': 3}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   3
# Current state:  162
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289065.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': 5, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   3
# Current state:  163
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289066.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.43, 'newState': {'x': 6, 'y': '3'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   3
# Current state:  203
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289067.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.39, 'newState': {'x': '6', 'y': 4}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   4
# Current state:  243
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289068.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.35, 'newState': {'x': 7, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   4
# Current state:  244
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289069.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.31, 'newState': {'x': 8, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  8   4
# Current state:  284
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289070.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.28, 'newState': {'x': 9, 'y': '4'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   4
# Current state:  324
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289071.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.25, 'newState': {'x': '9', 'y': 5}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  9   5
# Current state:  364
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289072.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.23, 'newState': {'x': 10, 'y': '5'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   5
# Current state:  365
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289073.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.21, 'newState': {'x': '10', 'y': 6}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  10   6
# Current state:  405
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289074.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.19, 'newState': {'x': 11, 'y': '6'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   6
# Current state:  406
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289075.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.17, 'newState': {'x': '11', 'y': 7}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   7
# Current state:  446
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289076.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.15, 'newState': {'x': '11', 'y': 8}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  11   8
# Current state:  447
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289077.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.14, 'newState': {'x': 12, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   8
# Current state:  448
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289078.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.12, 'newState': {'x': 13, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  13   8
# Current state:  488
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289079.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.11, 'newState': {'x': 12, 'y': '8'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   8
# Current state:  528
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289080.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.1, 'newState': {'x': '12', 'y': 9}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  12   9
# Current state:  488
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289081.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.09, 'newState': {'x': 13, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  13   9
# Current state:  489
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289082.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.08, 'newState': {'x': 14, 'y': '9'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   9
# Current state:  529
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289083.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.07, 'newState': {'x': '14', 'y': 10}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   10
# Current state:  569
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289084.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': '14', 'y': 11}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  14   11
# Current state:  570
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289085.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.06, 'newState': {'x': 15, 'y': '11'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  15   11
# Current state:  571
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289086.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '15', 'y': 12}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  15   12
# Current state:  611
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289087.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.05, 'newState': {'x': '15', 'y': 13}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  15   13
# Current state:  612
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289088.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': 16, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  16   13
# Current state:  613
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289089.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.04, 'newState': {'x': 17, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  17   13
# Current state:  653
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289090.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 18, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  18   13
# Current state:  693
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289091.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 19, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  19   13
# Current state:  733
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289092.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': 20, 'y': '13'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  20   13
# Current state:  773
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289093.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.03, 'newState': {'x': '20', 'y': 14}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  20   14
# Current state:  813
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289094.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '20', 'y': 15}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  20   15
# Current state:  814
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289095.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': 21, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  21   15
# Current state:  815
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289096.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': 22, 'y': '15'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  22   15
# Current state:  855
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289097.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.02, 'newState': {'x': '22', 'y': 16}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  22   16
# Current state:  895
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289098.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 23, 'y': '16'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  23   16
# Current state:  896
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289099.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '23', 'y': 17}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  23   17
# Current state:  936
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289100.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '23', 'y': 18}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  23   18
# Current state:  937
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289101.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 22, 'y': '18'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  22   18
# Current state:  938
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289102.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '22', 'y': 17}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  22   17
# Current state:  898
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289103.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 23, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  23   17
# Current state:  897
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289104.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 24, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  24   17
# Current state:  937
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289105.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 25, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  25   17
# Current state:  977
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289106.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': 24, 'y': '17'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  24   17
# Current state:  1017
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289107.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '24', 'y': 16}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  24   16
# Current state:  977
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289108.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': -0.01, 'newState': {'x': '24', 'y': 17}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  24   17
# Current state:  976
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289109.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -1, 'scoreIncrement': 0, 'newState': {'x': '24', 'y': 18}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  24   18
# Current state:  977
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -289110.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -100000, 'scoreIncrement': -417.46, 'newState': None}
# test except
# printing before terminal state:
#  {'code': 'OK', 'worldId': 5, 'runId': '50307', 'reward': -100000, 'scoreIncrement': -417.46, 'newState': None}
# 5  ended
# [  0.   3.   2.   2. 186.   6.   2.   2.   2.   2.   2.]
# 5  world selected for iteration
# learning rate alpha 0.9
# exploration rate epsilon 0.5
# {"code":"OK","teamId":1343}
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -1, 'newState': {'x': '0', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  0   1
# Current state:  0
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389111.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -0.9, 'newState': {'x': 1, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   1
# Current state:  1
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389112.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -0.81, 'newState': {'x': '1', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  1   2
# Current state:  41
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389113.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -0.73, 'newState': {'x': 2, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   2
# Current state:  42
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389114.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -0.66, 'newState': {'x': '2', 'y': 1}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  2   1
# Current state:  82
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389115.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -0.59, 'newState': {'x': 3, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  3   1
# Current state:  81
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389116.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -0.53, 'newState': {'x': 4, 'y': '1'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   1
# Current state:  121
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389117.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -0.48, 'newState': {'x': '4', 'y': 2}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  4   2
# Current state:  161
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389118.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -0.43, 'newState': {'x': 5, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  5   2
# Current state:  162
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389119.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -0.39, 'newState': {'x': 6, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  6   2
# Current state:  202
# Taken action to come to the current state from the previous state:  2
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389120.0
# printing the response:
#  {'code': 'OK', 'worldId': 5, 'runId': '50309', 'reward': -1, 'scoreIncrement': -0.35, 'newState': {'x': 7, 'y': '2'}}
# Visual of the given details is printed above
# World Number:  5
# Current state row and column:  7   2
# Current state:  242
# Taken action to come to the current state from the previous state:  0
# Reward of the current state:  -1.0
# cumulative reward from the world so far:  -389121.0
